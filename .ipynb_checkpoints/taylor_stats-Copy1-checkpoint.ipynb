# %%
import matplotlib.pyplot as plt 
import numpy.ma as ma
import xarray as xr
import pandas as pd
import numpy as np
# ds083 GFS NAM
# p1s1 p2s2 p7s7

# %%
expruns = ['20120816_d03_gfs05_p1r1', '20120816_d03_gfs05_p1r3','20120816_d03_gfs05_p1r5',
           '20120816_d03_gfs05_p2r1', '20120816_d03_gfs05_p2r3','20120816_d03_gfs05_p2r5'
          '20120816_d03_gfs05_p1r1', '20120816_d03_gfs05_p1r3','20120816_d03_gfs05_p1r5',
           '20120816_d03_gfs05_p2r1', '20120816_d03_gfs05_p2r3','20120816_d03_']
expnames = ['g1r1', 'g1r3', 'g1r5', 'g2r1', 'g2r3', 'g2r5','n1r1', 'n1r3', 'n1r5', 'n2r1', 'n2r3', 'n2r5']
ids = [0,1,2,7,12,17,22,27,32,37,42,47]
levlabel = ['30m', '40m', '50m', '100m', '150m', '200m', '250m', '300m', '350m', '400m', '450m', '500m']
levs=[30,40,50,100,150,200,250,300,350,400,450,500]
levn=['30','40','50','100','150','200','250','300','350','400','450','500']
t1, t2, t3, t4 = '2012-08-16 12:00', '2012-08-17 12:00', '2012-08-18 12:00', '2012-08-19 12:00'

expruns[1]
# Out:
# '20120816_d03_gfs05_p1r3'

# %%
# READ WRF INTERP DATA

g1r1 = xr.open_dataset('interp30/sodar_g1r1.nc')['uv30'].to_pandas()
g1r3 = xr.open_dataset('interp30/sodar_g1r3.nc')['uv30'].to_pandas()
g1r5 = xr.open_dataset('interp30/sodar_g1r5.nc')['uv30'].to_pandas()
g2r1 = xr.open_dataset('interp30/sodar_g2r1.nc')['uv30'].to_pandas()
g2r3 = xr.open_dataset('interp30/sodar_g2r3.nc')['uv30'].to_pandas()
g2r5 = xr.open_dataset('interp30/sodar_g2r5.nc')['uv30'].to_pandas()
n1r1 = xr.open_dataset('interp30/sodar_n1r1.nc')['uv30'].to_pandas()
n1r3 = xr.open_dataset('interp30/sodar_n1r3.nc')['uv30'].to_pandas()
n1r5 = xr.open_dataset('interp30/sodar_n1r5.nc')['uv30'].to_pandas()
n2r1 = xr.open_dataset('interp30/sodar_n2r1.nc')['uv30'].to_pandas()
n2r3 = xr.open_dataset('interp30/sodar_n2r3.nc')['uv30'].to_pandas()
n2r5 = xr.open_dataset('interp30/sodar_n2r5.nc')['uv30'].to_pandas()

drw1 = xr.open_dataset('interp30/sodar_g1r1.nc')['wd30'].to_pandas()
drw2 = xr.open_dataset('interp30/sodar_g1r3.nc')['wd30'].to_pandas()
drw3 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].to_pandas()
drw4 = xr.open_dataset('interp30/sodar_g2r1.nc')['wd30'].to_pandas()
drw5 = xr.open_dataset('interp30/sodar_g2r3.nc')['wd30'].to_pandas()
drw6 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].to_pandas()

tvg1r1 = xr.open_dataset('interp30/sodar_g1r1.nc')['tv30'].to_pandas()
tvg1r3 = xr.open_dataset('interp30/sodar_g1r3.nc')['tv30'].to_pandas()
tvg1r5 = xr.open_dataset('interp30/sodar_g1r5.nc')['tv30'].to_pandas()
tvg2r1 = xr.open_dataset('interp30/sodar_g2r1.nc')['tv30'].to_pandas()
tvg2r3 = xr.open_dataset('interp30/sodar_g2r3.nc')['tv30'].to_pandas()
tvg2r5 = xr.open_dataset('interp30/sodar_g2r5.nc')['tv30'].to_pandas()
tvn1r1 = xr.open_dataset('interp30/sodar_n1r1.nc')['tv30'].to_pandas()
tvn1r3 = xr.open_dataset('interp30/sodar_n1r3.nc')['tv30'].to_pandas()
tvn1r5 = xr.open_dataset('interp30/sodar_n1r5.nc')['tv30'].to_pandas()
tvn2r1 = xr.open_dataset('interp30/sodar_n2r1.nc')['tv30'].to_pandas()
tvn2r3 = xr.open_dataset('interp30/sodar_n2r3.nc')['tv30'].to_pandas()
tvn2r5 = xr.open_dataset('interp30/sodar_n2r5.nc')['tv30'].to_pandas()

sread_w =  pd.read_pickle('sodar_sp.pk')
sread_d =  pd.read_pickle('sodar_dd.pk')
sread_t =  pd.read_pickle('sodar_tv.pk')

sodarw =  sread_w.iloc[:,ids][t1:t4]
sodard =  sread_d.iloc[:,ids][t1:t4]
sodart =  sread_t.iloc[:,ids][t1:t4]

# %%
plt.plot(sread_w.iloc[:,1][t1:t4])
pandas = xr.open_dataset('interp30/sodar_g1r1.nc')['uv30'].to_pandas()
plt.plot(pandas.iloc[:,1])
#plt.plot(g1r1.iloc[:,2])
#plt.plot(sodarw[:,2])

# %%
inds = np.append(np.arange(0,25),np.arange(48,73))
indl = np.append(np.arange(24,49),np.arange(72,97))

sea = sodarw.iloc[inds]
llj = sodarw.iloc[indl]

print(sea.shape, llj.shape, indl.shape, inds.shape)
# Out:
# (50, 12) (50, 12) (50,) (50,)

# %%
lev = 2

wg1 = pd.DataFrame(g1r1.iloc[:,lev])
wg2 = pd.DataFrame(g1r3.iloc[:,lev])
wg3 = pd.DataFrame(g1r5.iloc[:,lev])
wg4 = pd.DataFrame(g2r1.iloc[:,lev])
wg5 = pd.DataFrame(g2r3.iloc[:,lev])
wg6 = pd.DataFrame(g2r5.iloc[:,lev])
wn1 = pd.DataFrame(n1r1.iloc[:,lev])
wn2 = pd.DataFrame(n1r3.iloc[:,lev])
wn3 = pd.DataFrame(n1r5.iloc[:,lev])
wn4 = pd.DataFrame(n2r1.iloc[:,lev])
wn5 = pd.DataFrame(n2r3.iloc[:,lev])
wn6 = pd.DataFrame(n2r5.iloc[:,lev])

wga = (wg1+wg2+wg3+wg4+wg5+wg6)/6
sod = sodarw.iloc[:,lev]

plt.plot(sod, label='SODAR'); 
plt.plot(wg1, label='wg1 WRF'); 

plt.xticks(rotation=20); plt.legend();

plt.xlabel('Dia-Hora')
plt.ylabel('Velocidad (m/s)')
plt.suptitle('Viento Obs. vs media Pronosticos a '+levlabel[lev]+' (Agosto 2012)', y=1.02);
plt.tight_layout()

#plt.savefig('figs/lev'+str(lev)+'_sodarw2.png')

# %%
#          time,lev
lev=11
r = llj.iloc[:,lev]
validt = list(np.where(~r.isnull())[0])
r = llj.iloc[validt,lev]
#g1r1.iloc[indl,lev][idx[:,lev]]
p = g1r1.iloc[indl,lev][validt]  #[idx[:,lev]]

# %%
#          time,lev
#r = [llj.iloc[:,lev] for i in range(12)] 
#validt = [list(np.where(~r[i].isnull())[0]) for i in range(12)]
#r = [llj.iloc[validt[i],lev] for i in range(12)] 
#
##          g1r1.iloc[indl,lev][validt]
#p = [eval(expnames[i]+'.iloc[indl,lev][validt['+str(i)+']]') for i in range(12)]

# %%
j=0
lev = j
print(lev)
    #          time,lev
r = [llj.iloc[:,lev] for i in range(12)] 
validt = [list(np.where(~r[i].isnull())[0]) for i in range(12)]
r = [llj.iloc[validt[i],lev] for i in range(12)] 

#          g1r1.iloc[indl,lev][validt]
p = [eval(expnames[i]+'.iloc[indl,lev][validt['+str(i)+']]') for i in range(12)]
# Out:
# 0

# %%
from IPython.display import display
for j in range(12):
    lev = j
    print(lev)
    ######    LOW LEVEL JET    #####
    #          time,lev
    r = [llj.iloc[:,lev] for i in range(12)] 
    validt = [list(np.where(~r[i].isnull())[0]) for i in range(12)]
    r = [llj.iloc[validt[i],lev] for i in range(12)] 
    #          g1r1.iloc[indl,lev][validt]
    p = [eval(expnames[i]+'.iloc[indl,lev][validt['+str(i)+']]') for i in range(12)] 
    
    pm = [np.mean(p[i]) for i in range(12)] 
    rm = [np.mean(r[i]) for i in range(12)]
    p_pm = [(p[i] - pm[i]) for i in range(12)]
    r_rm = [(r[i] - rm[i]) for i in range(12)]
    crmsd = [np.sqrt(np.average(np.square((p_pm[i]) - (r_rm[i])))) for i in range(12)]
    sdevp = [np.std(p[i]) for i in range(12)]
    sdevr = [np.std(r[i]) for i in range(12)]
    #  ratio:  Case_Variance/Reference_Variance
    ratio = [(np.var(p[i]) / np.var(r[i])) for i in range(12)]
    bias = [(np.average(p[i]) - np.average(r[i])) for i in range(12)]
    sdev = [[sdevr[i], sdevp[i]] for i in range(12)];
    ccoef =[ np.corrcoef(r[i], p[i])[1,0] for i in range(12)]
    sdev = np.array(np.append(sdevr[0], sdevp))
    crmsd = np.array(np.append(0, crmsd))
    ccoef = np.array(np.append(1, ccoef))
    bias = np.append(0,bias)
    ratio = np.append(1,ratio)
    print(expnames[0], sdev[0], crmsd[0], ccoef[0])
    #print(np.size(r[0]), np.size(p[0]))

    ######    LOW LEVEL JET    #####
    xnames=['LLJ_'+levlabel[lev]]+expnames
    media = np.array(np.append(rm[0], pm))
    import pandas as pd
    pd.options.display.float_format = '{:.3f},'.format
    print ('JET NOCTURNO NIVEL '+levlabel[lev])
    #pd.DataFrame([media,bias,sdev,ratio,ccoef], columns=xnames, index=['media','bias','sdev','ratio','ccoef'])
    display(pd.DataFrame([media,ccoef,ratio,sdev,bias], columns=xnames, index=['media','ccoef','ratio','sdev','bias']))
# Out:
# 0
# g1r1 1.4988476476391233 0.0 1.0
# JET NOCTURNO NIVEL 30m
#        LLJ_30m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media   3.036,  1.520,  1.770,  1.419,  1.497,  1.894,  1.627,  1.345,
# ccoef   1.000, -0.214,  0.086, -0.283, -0.183, -0.416, -0.001,  0.017,
# ratio   1.000,  0.181,  0.251,  0.132,  0.313,  0.224,  0.286,  0.158,
# sdev    1.499,  0.638,  0.750,  0.545,  0.838,  0.710,  0.802,  0.596,
# bias    0.000, -1.516, -1.267, -1.617, -1.539, -1.142, -1.409, -1.691,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.732,  1.274,  1.517,  1.861,  1.397,
# ccoef  0.161,  0.038, -0.157,  0.034, -0.158,
# ratio  0.237,  0.116,  0.161,  0.213,  0.305,
# sdev   0.730,  0.511,  0.601,  0.692,  0.827,
# bias  -1.304, -1.762, -1.519, -1.175, -1.639,
# 1
# g1r1 1.9165868516714812 0.0 1.0
# JET NOCTURNO NIVEL 40m
#        LLJ_40m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media   2.522,  1.542,  1.840,  1.443,  1.542,  1.936,  1.653,  1.356,
# ccoef   1.000, -0.311,  0.108, -0.356, -0.249, -0.347, -0.132, -0.005,
# ratio   1.000,  0.121,  0.164,  0.091,  0.188,  0.147,  0.188,  0.094,
# sdev    1.917,  0.666,  0.776,  0.579,  0.831,  0.736,  0.832,  0.589,
# bias    0.000, -0.980, -0.682, -1.080, -0.980, -0.586, -0.869, -1.166,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.757,  1.272,  1.532,  1.923,  1.458,
# ccoef  0.146,  0.029, -0.132,  0.050, -0.170,
# ratio  0.151,  0.074,  0.095,  0.147,  0.190,
# sdev   0.745,  0.521,  0.590,  0.735,  0.835,
# bias  -0.765, -1.250, -0.990, -0.599, -1.064,
# 2
# g1r1 2.0838378439792287 0.0 1.0
# JET NOCTURNO NIVEL 50m
#        LLJ_50m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media   2.953,  1.514,  1.872,  1.422,  1.551,  1.956,  1.644,  1.331,
# ccoef   1.000, -0.291,  0.119, -0.380, -0.194, -0.289, -0.112, -0.046,
# ratio   1.000,  0.102,  0.148,  0.079,  0.158,  0.132,  0.168,  0.075,
# sdev    2.084,  0.666,  0.801,  0.586,  0.827,  0.757,  0.853,  0.572,
# bias    0.000, -1.439, -1.081, -1.531, -1.402, -0.996, -1.308, -1.622,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.750,  1.261,  1.522,  1.972,  1.483,
# ccoef  0.150, -0.049, -0.124,  0.100, -0.188,
# ratio  0.134,  0.062,  0.078,  0.141,  0.163,
# sdev   0.762,  0.520,  0.584,  0.782,  0.841,
# bias  -1.203, -1.692, -1.431, -0.981, -1.470,
# 3
# g1r1 2.8543173544649867 0.0 1.0
# JET NOCTURNO NIVEL 100m
#        LLJ_100m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    3.864,  1.386,  2.008,  1.338,  1.563,  2.056,  1.595,  1.245,
# ccoef    1.000, -0.247,  0.441, -0.272, -0.072,  0.061, -0.100, -0.106,
# ratio    1.000,  0.059,  0.122,  0.048,  0.081,  0.103,  0.090,  0.034,
# sdev     2.854,  0.691,  0.999,  0.626,  0.814,  0.918,  0.858,  0.525,
# bias     0.000, -2.478, -1.856, -2.525, -2.301, -1.808, -2.268, -2.619,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.743,  1.241,  1.524,  2.158,  1.585,
# ccoef  0.279, -0.112, -0.096,  0.155, -0.205,
# ratio  0.100,  0.036,  0.047,  0.145,  0.097,
# sdev   0.902,  0.542,  0.620,  1.087,  0.889,
# bias  -2.121, -2.623, -2.339, -1.706, -2.279,
# 4
# g1r1 3.1083715093276734 0.0 1.0
# JET NOCTURNO NIVEL 150m
#        LLJ_150m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    4.498,  1.299,  2.120,  1.289,  1.547,  2.253,  1.554,  1.218,
# ccoef    1.000, -0.386,  0.485, -0.286, -0.127,  0.318, -0.115, -0.244,
# ratio    1.000,  0.050,  0.151,  0.042,  0.066,  0.153,  0.062,  0.032,
# sdev     3.108,  0.697,  1.209,  0.638,  0.797,  1.217,  0.774,  0.558,
# bias     0.000, -3.199, -2.379, -3.210, -2.951, -2.245, -2.944, -3.281,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.771,  1.273,  1.593,  2.249,  1.641,
# ccoef  0.240, -0.112, -0.166,  0.164, -0.277,
# ratio  0.104,  0.034,  0.047,  0.204,  0.088,
# sdev   1.005,  0.571,  0.675,  1.404,  0.922,
# bias  -2.728, -3.225, -2.905, -2.249, -2.857,
# 5
# g1r1 3.342499663425563 0.0 1.0
# JET NOCTURNO NIVEL 200m
#        LLJ_200m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    4.884,  1.274,  2.245,  1.282,  1.521,  2.603,  1.542,  1.253,
# ccoef    1.000, -0.580,  0.496, -0.456, -0.271,  0.462, -0.295, -0.232,
# ratio    1.000,  0.044,  0.170,  0.035,  0.063,  0.232,  0.050,  0.035,
# sdev     3.342,  0.701,  1.379,  0.625,  0.840,  1.609,  0.749,  0.624,
# bias     0.000, -3.610, -2.639, -3.602, -3.363, -2.281, -3.342, -3.631,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.782,  1.332,  1.681,  2.319,  1.714,
# ccoef  0.238, -0.042, -0.108,  0.147, -0.266,
# ratio  0.089,  0.028,  0.048,  0.237,  0.077,
# sdev   0.999,  0.556,  0.734,  1.626,  0.927,
# bias  -3.102, -3.552, -3.203, -2.565, -3.170,
# 6
# g1r1 3.6201136718107545 0.0 1.0
# JET NOCTURNO NIVEL 250m
#        LLJ_250m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    5.391,  1.293,  2.430,  1.303,  1.525,  3.107,  1.582,  1.356,
# ccoef    1.000, -0.649,  0.453, -0.596, -0.515,  0.410, -0.534, -0.231,
# ratio    1.000,  0.038,  0.171,  0.028,  0.061,  0.275,  0.052,  0.032,
# sdev     3.620,  0.708,  1.499,  0.609,  0.894,  1.900,  0.825,  0.651,
# bias     0.000, -4.098, -2.961, -4.088, -3.865, -2.284, -3.809, -4.034,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.787,  1.398,  1.842,  2.431,  1.843,
# ccoef  0.205, -0.087, -0.099,  0.086, -0.222,
# ratio  0.070,  0.023,  0.046,  0.235,  0.063,
# sdev   0.955,  0.552,  0.779,  1.753,  0.911,
# bias  -3.604, -3.993, -3.549, -2.959, -3.548,
# 7
# g1r1 3.7571759119494708 0.0 1.0
# JET NOCTURNO NIVEL 300m
#        LLJ_300m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    5.410,  1.383,  2.500,  1.349,  1.543,  3.367,  1.617,  1.496,
# ccoef    1.000, -0.555,  0.462, -0.628, -0.643,  0.379, -0.515, -0.150,
# ratio    1.000,  0.029,  0.152,  0.022,  0.053,  0.275,  0.042,  0.026,
# sdev     3.757,  0.635,  1.467,  0.555,  0.869,  1.969,  0.771,  0.609,
# bias     0.000, -4.027, -2.910, -4.061, -3.867, -2.043, -3.793, -3.914,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.825,  1.378,  1.960,  2.459,  1.874,
# ccoef  0.225, -0.017,  0.131,  0.082, -0.036,
# ratio  0.051,  0.023,  0.032,  0.199,  0.048,
# sdev   0.852,  0.567,  0.676,  1.676,  0.821,
# bias  -3.585, -4.032, -3.450, -2.951, -3.536,
# 8
# g1r1 3.91885200929956 0.0 1.0
# JET NOCTURNO NIVEL 350m
#        LLJ_350m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    6.462,  1.469,  2.655,  1.321,  1.699,  3.775,  1.772,  1.565,
# ccoef    1.000, -0.348,  0.332, -0.396, -0.686,  0.232, -0.467, -0.023,
# ratio    1.000,  0.030,  0.140,  0.022,  0.083,  0.259,  0.048,  0.022,
# sdev     3.919,  0.684,  1.464,  0.579,  1.129,  1.996,  0.860,  0.579,
# bias     0.000, -4.993, -3.807, -5.141, -4.763, -2.687, -4.690, -4.897,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.894,  1.304,  2.058,  2.493,  1.868,
# ccoef  0.332,  0.023,  0.290,  0.120, -0.008,
# ratio  0.044,  0.022,  0.032,  0.177,  0.047,
# sdev   0.822,  0.579,  0.704,  1.648,  0.851,
# bias  -4.568, -5.158, -4.404, -3.969, -4.594,
# 9
# g1r1 3.661711557408176 0.0 1.0
# JET NOCTURNO NIVEL 400m
#        LLJ_400m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    6.933,  1.529,  2.589,  1.262,  1.746,  3.806,  1.736,  1.563,
# ccoef    1.000,  0.225,  0.273,  0.079, -0.511,  0.030, -0.106,  0.338,
# ratio    1.000,  0.037,  0.137,  0.023,  0.104,  0.307,  0.065,  0.024,
# sdev     3.662,  0.705,  1.353,  0.559,  1.183,  2.028,  0.933,  0.570,
# bias     0.000, -5.404, -4.345, -5.671, -5.187, -3.127, -5.198, -5.370,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  1.867,  1.190,  2.025,  2.325,  1.699,
# ccoef  0.493,  0.306,  0.656, -0.142,  0.263,
# ratio  0.037,  0.026,  0.043,  0.174,  0.042,
# sdev   0.707,  0.594,  0.761,  1.529,  0.747,
# bias  -5.066, -5.744, -4.908, -4.608, -5.234,
# 10
# g1r1 3.453963504278655 0.0 1.0
# JET NOCTURNO NIVEL 450m
#        LLJ_450m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    7.363,  1.994,  2.783,  1.599,  1.972,  3.733,  2.039,  1.598,
# ccoef    1.000,  0.457,  0.238,  0.062, -0.371, -0.025, -0.109,  0.650,
# ratio    1.000,  0.040,  0.102,  0.031,  0.134,  0.265,  0.106,  0.020,
# sdev     3.454,  0.690,  1.104,  0.612,  1.263,  1.779,  1.123,  0.486,
# bias     0.000, -5.370, -4.580, -5.764, -5.391, -3.631, -5.325, -5.765,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  2.170,  1.248,  2.176,  2.132,  1.660,
# ccoef  0.596,  0.378,  0.548, -0.238,  0.289,
# ratio  0.042,  0.030,  0.049,  0.148,  0.058,
# sdev   0.705,  0.603,  0.763,  1.327,  0.831,
# bias  -5.193, -6.116, -5.188, -5.231, -5.703,
# 11
# g1r1 2.719040777553731 0.0 1.0
# JET NOCTURNO NIVEL 500m
#        LLJ_500m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    7.213,  2.276,  2.876,  1.771,  2.059,  3.718,  2.058,  1.456,
# ccoef    1.000,  0.354, -0.161, -0.282, -0.387, -0.255, -0.358,  0.747,
# ratio    1.000,  0.072,  0.207,  0.047,  0.216,  0.403,  0.128,  0.012,
# sdev     2.719,  0.728,  1.236,  0.589,  1.264,  1.726,  0.972,  0.293,
# bias     0.000, -4.938, -4.337, -5.443, -5.154, -3.496, -5.156, -5.758,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  2.416,  1.283,  2.285,  2.203,  1.461,
# ccoef  0.397,  0.355,  0.329, -0.529,  0.097,
# ratio  0.087,  0.031,  0.059,  0.266,  0.063,
# sdev   0.801,  0.475,  0.659,  1.402,  0.680,
# bias  -4.797, -5.930, -4.928, -5.010, -5.753,

# %%
str(0)
# Out:
# '0'

# %%
######    LOW LEVEL JET    #####
xnames=['LLJ_'+levlabel[lev]]+expnames
media = np.array(np.append(rm[0], pm))
import pandas as pd
pd.options.display.float_format = '{:.3f},'.format
print ('JET NOCTURNO NIVEL '+levlabel[lev])
#pd.DataFrame([media,bias,sdev,ratio,ccoef], columns=xnames, index=['media','bias','sdev','ratio','ccoef'])
pd.DataFrame([media,ccoef,ratio,sdev,bias], columns=xnames, index=['media','ccoef','ratio','sdev','bias'])
# Out:
# JET NOCTURNO NIVEL 500m
#        LLJ_500m    g1r1    g1r3    g1r5    g2r1    g2r3    g2r5    n1r1  \
# media    7.213,  2.276,  2.876,  1.771,  2.059,  3.718,  2.058,  1.456,
# ccoef    1.000,  0.354, -0.161, -0.282, -0.387, -0.255, -0.358,  0.747,
# ratio    1.000,  0.072,  0.207,  0.047,  0.216,  0.403,  0.128,  0.012,
# sdev     2.719,  0.728,  1.236,  0.589,  1.264,  1.726,  0.972,  0.293,
# bias     0.000, -4.938, -4.337, -5.443, -5.154, -3.496, -5.156, -5.758,
#
#          n1r3    n1r5    n2r1    n2r3    n2r5
# media  2.416,  1.283,  2.285,  2.203,  1.461,
# ccoef  0.397,  0.355,  0.329, -0.529,  0.097,
# ratio  0.087,  0.031,  0.059,  0.266,  0.063,
# sdev   0.801,  0.475,  0.659,  1.402,  0.680,
# bias  -4.797, -5.930, -4.928, -5.010, -5.753,

# %%
######    LOW LEVEL JET    #####
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(r[0][:25], label='OBS')
for i in range(3):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()

#plt.xticks(6*np.arange(5), g1r1[indl][::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5), rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))

plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')

plt.subplot(1, 2, 2)
plt.plot(r[0][25:], label='OBS')
for i in range(3):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()
#plt.xticks(6*np.arange(5),  g1r1[indl][25::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5),  rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))
#plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')
#plt.ylim(22,32)
plt.suptitle('Jet Nocturno '+levlabel[lev]+' Agosto 2012', y=1);
plt.tight_layout()

plt.savefig('figs/lev'+str(lev)+'_LLJ.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a3357d303533> in <module>
#      30 #plt.ylim(22,32)
#      31 plt.suptitle('Jet Nocturno '+levlabel[lev]+' Agosto 2012', y=1);
# ---> 32 plt.tight_layout()
#      33
#      34 plt.savefig('figs/lev'+str(lev)+'_LLJ.png')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1373         labels) will fit into. Default is (0, 0, 1, 1).
#    1374     """
# -> 1375     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1376
#    1377
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2474         kwargs = get_tight_layout_figure(
#    2475             self, self.axes, subplotspec_list, renderer,
# -> 2476             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2477         if kwargs:
#    2478             self.subplots_adjust(**kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     360                                      subplot_list=subplot_list,
#     361                                      ax_bbox_list=ax_bbox_list,
# --> 362                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     363
#     364     # kwargs can be none if tight_layout fails...
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     109             continue
#     110
# --> 111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in <listcomp>(.0)
#     110
#     111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#     114                                      fig.transFigure.inverted())
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4355
#    4356         if self.axison:
# -> 4357             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4358             if bb_xaxis:
#    4359                 bb.append(bb_xaxis)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1078         """
#    1079         major_locs = self.get_majorticklocs()
# -> 1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     258         """Return the tick labels for all the ticks at once."""
#     259         self.set_locs(values)
# --> 260         return [self(value, i) for i, value in enumerate(values)]
#     261
#     262     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     258         """Return the tick labels for all the ticks at once."""
#     259         self.set_locs(values)
# --> 260         return [self(value, i) for i, value in enumerate(values)]
#     261
#     262     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#    1033         if isinstance(fmt, str):
#    1034             self._formatter = DateFormatter(fmt, self._tz)
# -> 1035             result = self._formatter(x, pos)
#    1036         elif callable(fmt):
#    1037             result = fmt(x, pos)
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#     596     def __call__(self, x, pos=0):
#     597         if x == 0:
# --> 598             raise ValueError('DateFormatter found a value of x=0, which is '
#     599                              'an illegal date; this usually occurs because '
#     600                              'you have not informed the axis that it is '
#
# ValueError: DateFormatter found a value of x=0, which is an illegal date; this usually occurs because you have not informed the axis that it is plotting dates, e.g., with ax.xaxis_date()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2063                         orientation=orientation,
#    2064                         dryrun=True,
# -> 2065                         **kwargs)
#    2066                     renderer = self.figure._cachedRenderer
#    2067                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1078         """
#    1079         major_locs = self.get_majorticklocs()
# -> 1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     258         """Return the tick labels for all the ticks at once."""
#     259         self.set_locs(values)
# --> 260         return [self(value, i) for i, value in enumerate(values)]
#     261
#     262     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     258         """Return the tick labels for all the ticks at once."""
#     259         self.set_locs(values)
# --> 260         return [self(value, i) for i, value in enumerate(values)]
#     261
#     262     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#    1033         if isinstance(fmt, str):
#    1034             self._formatter = DateFormatter(fmt, self._tz)
# -> 1035             result = self._formatter(x, pos)
#    1036         elif callable(fmt):
#    1037             result = fmt(x, pos)
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#     596     def __call__(self, x, pos=0):
#     597         if x == 0:
# --> 598             raise ValueError('DateFormatter found a value of x=0, which is '
#     599                              'an illegal date; this usually occurs because '
#     600                              'you have not informed the axis that it is '
#
# ValueError: DateFormatter found a value of x=0, which is an illegal date; this usually occurs because you have not informed the axis that it is plotting dates, e.g., with ax.xaxis_date()

# %%
import skill_metrics as sm
plt.figure(figsize=(10,9))

label = ['REF', '1', '2', '3', '4', '5', '6', '1', '2', '3', '4', '5', '6']
sm.taylor_diagram(sdev,crmsd,ccoef, markerLabel = label, markerLabelColor = 'b', 
                  tickRMS= np.arange(3,5,1), tickRMSangle = 170.0, 
                  colRMS = 'm', styleRMS = ':', widthRMS = 2.0,
                  tickSTD = np.arange(0,2.5,0.5), axismax = 2.0,
                  colSTD = 'b', styleSTD = '-.', widthSTD = 1.0,
                  colCOR = 'k', styleCOR = '--', widthCOR = 1.0)
plt.title(' LLJ a '+levlabel[lev], y=1.0);
sodsdev = "{:.2f}".format( sdev[0] )
plt.scatter(sdev[0],0.02, color='b')
plt.annotate('SODAR \n STD DEV \n  '+sodsdev, (sdev[0]-.2, 0.1), color='b');
print(expnames[0], sdev[0], crmsd[0], ccoef[0])
#plt.savefig('figs/lev'+str(lev)+'_Taylor_LLJ.png')

# %%
######     BRISA MARINA   ######
sodmsk = ma.masked_invalid(sea) 
inv = sodmsk.mask
idx = ~inv
sodmsk.shape
test = 'wrf'

#p = [eval(test+str(i)+'[inds,lev][idx[:,lev]]') for i in range(1,7)]
p = [eval(str(i)+'[indl,lev][idx[:,lev]]') for i in expnames]

pm = [np.mean(p[i]) for i in range(12)] 
r = [sodmsk[:,lev][idx[:,lev]].data for i in range(12)]
rm = [np.mean(r[i]) for i in range(12)]
p_pm = [(p[i] - pm[i]) for i in range(12)]
r_rm = [(r[i] - rm[i]) for i in range(12)]
crmsd = [np.sqrt(np.average(np.square((p_pm[i]) - (r_rm[i])))) for i in range(12)]
sdevp = [np.std(p[i]) for i in range(12)]
sdevr = [np.std(r[i]) for i in range(12)]
#  ratio:  Case_Variance/Reference_Variance
ratio = [(np.var(p[i]) / np.var(r[i])) for i in range(12)]
bias = [(np.average(p[i]) - np.average(r[i])) for i in range(12)]
sdev = [[sdevr[i], sdevp[i]] for i in range(12)];
ccoef =[ np.corrcoef(r[i], p[i])[1,0] for i in range(12)]
sdev = np.array(np.append(sdevr[0], sdevp))
crmsd = np.array(np.append(0, crmsd))
ccoef = np.array(np.append(1, ccoef))
bias = np.append(0,bias)
ratio = np.append(1,ratio)
print(test, sdev[0], crmsd[0], ccoef[0])
print(np.size(r[0]), np.size(p[0]))

# %%
######     BRISA MARINA   ######
xnames=['SB_'+levlabel[lev]]+expnames
media = np.array(np.append(rm[0], pm))
import pandas as pd
pd.options.display.float_format = '{:.3f},'.format
print ('BRISA MARINA NIVEL '+levlabel[lev])
pd.DataFrame([media,ccoef,ratio,sdev,bias], columns=xnames, index=['media','ccoef','ratio','sdev','bias'])

# %%
######     BRISA MARINA   ######
plt.figure(figsize=(11,4))
plt.subplot(1, 2, 1)
plt.plot(r[0][:24], label='OBS')
for i in range(3):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()
#plt.xticks(6*np.arange(5), n1r1.index[inds][::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5), rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))
plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')

plt.subplot(1, 2, 2)
plt.plot(r[0][25:], label='OBS')
for i in range(3):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()
#plt.xticks(6*np.arange(5), w1.index[inds][25::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5), rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))
#plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')
#plt.ylim(22,32)

plt.suptitle('Brisa Marina '+levlabel[lev]+' Agosto 2012', y=1);
plt.tight_layout()

plt.savefig('figs/lev'+str(lev)+'_SB.png')

# %%
test = 'tv'
lev = 3
######    ######

p = [eval(test+str(i)+'[inds,lev]') for i in expnames]
r = sodart[inds,lev]
#pm = [np.mean(p[i]) for i in range(6)] 
#rm = [np.mean(r[i]) for i in range(6)]

######     BRISA MARINA TV ######
plt.figure(figsize=(11,4))
plt.subplot(1, 2, 1)
plt.plot(r[:24], label='OBS')
for i in range(3):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][:25], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()
#plt.xticks(6*np.arange(5), w1.index[inds][::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5), rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))
plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')

plt.subplot(1, 2, 2)
plt.plot(r[25:], label='OBS')
for i in range(3):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8)
for i in range(3,6,1):
    plt.plot(p[i][25:], label=expnames[i], linewidth=.8, linestyle='--')
plt.legend()
#plt.xticks(6*np.arange(5), w1.index[inds][25::6].strftime('%d-%Hh'), rotation=20);
plt.xticks(6*np.arange(5), rotation=20);
#plt.yticks(np.arange(22,33), range(22,33))
#plt.ylabel('Velocidad [m/s]')
plt.xlabel('Dia-Hora')
#plt.ylim(22,32)

plt.suptitle('Temp Virtual Brisa Marina '+levlabel[lev]+' Agosto 2012', y=1);
plt.tight_layout()

plt.savefig('figs/lev'+str(lev)+'_TV_SB.png')

# %%
media

# %%
dicts = {}
keys = range(4)
values = ["Hi", "I", "am", "John"]
for i in keys:
        dicts[i] = values[i]
print(dicts)

# %%
############################################### TABLA DE DATOS TAYLOR ###################

# %%
ids = [0,1,2,7,12,17,22,27,32,37,42,47]
lev = 11
ii = 24
ee = 121

wg1 = pd.DataFrame(g1r1[ii:ee,lev], index=sodw.index)
wg2 = pd.DataFrame(g1r3[ii:ee,lev], index=sodw.index)
wg3 = pd.DataFrame(g1r5[ii:ee,lev], index=sodw.index)
wg4 = pd.DataFrame(g2r1[ii:ee,lev], index=sodw.index)
wg5 = pd.DataFrame(g2r3[ii:ee,lev], index=sodw.index)
wg6 = pd.DataFrame(g2r5[ii:ee,lev], index=sodw.index)
wn1 = pd.DataFrame(n1r1[ii:ee,lev], index=sodw.index)
wn2 = pd.DataFrame(n1r3[ii:ee,lev], index=sodw.index)
wn3 = pd.DataFrame(n1r5[ii:ee,lev], index=sodw.index)
wn4 = pd.DataFrame(n2r1[ii:ee,lev], index=sodw.index)
wn5 = pd.DataFrame(n2r3[ii:ee,lev], index=sodw.index)
wn6 = pd.DataFrame(n2r5[ii:ee,lev], index=sodw.index)
wga = (wg1+wg2+wg3+wg4+wg5+wg6+wn1+wn2+wn3+wn4+wn5+wn6)/12
sod = sodw.iloc[:,lev]
#plt.plot(r[0])
#plt.plot(p[0]); plt.plot(p[2]);

plt.plot(sod, label='SODAR'); 
plt.plot(wga, label='media WRF'); 
#plt.plot(w1, label='w1', linewidth=.8); 
#plt.plot(w2, label='w2', linewidth=.8); 
#plt.plot(w3, label='w3', linewidth=.8); 
#plt.plot(w4, label='w4', linewidth=.8); 
#plt.plot(w5, label='w5', linewidth=.8); 
#plt.plot(w6, label='w6', linewidth=.8); 
plt.xticks(rotation=20); plt.legend();
#locs, labels = plt.xticks()
#plt.xticks([]) 
#plt.xticks(6*np.arange(5),  w1.index[25::6].strftime('%d-%Hh'), rotation=20);

plt.xlabel('Dia-Hora')
plt.ylabel('Velocidad (m/s)')
plt.suptitle('Observaciones Sodar y media Pronosticos a '+levlabel[lev]+' (Agosto 2012)', y=1.05);
plt.tight_layout()

#plt.savefig('figs/lev'+str(lev)+'_sodarw2.png')

# %%
ids = [0,1,2,7,12,17,22,27,32,37,42,47]

######     BRISA MARINA   ######
sodmsk = ma.masked_invalid(sea) 
inv = sodmsk.mask
idx = ~inv

#p = [eval(test+str(i)+'[inds,lev][idx[:,lev]]') for i in range(1,7)]
p = [eval(str(i)+'[indl,lev][idx[:,lev]]') for i in expnames]
pm = [np.mean(p[i]) for i in range(12)] 
r = [sodmsk[:,lev][idx[:,lev]].data for i in range(12)]
rm = [np.mean(r[i]) for i in range(12)]
p_pm = [(p[i] - pm[i]) for i in range(12)]
r_rm = [(r[i] - rm[i]) for i in range(12)]
crmsd = [np.sqrt(np.average(np.square((p_pm[i]) - (r_rm[i])))) for i in range(12)]
sdevp = [np.std(p[i]) for i in range(12)]
sdevr = [np.std(r[i]) for i in range(12)]
#  ratio:  Case_Variance/Reference_Variance
ratio = [(np.var(p[i]) / np.var(r[i])) for i in range(12)]
bias = [(np.average(p[i]) - np.average(r[i])) for i in range(12)]
sdev = [[sdevr[i], sdevp[i]] for i in range(12)];
ccoef =[ np.corrcoef(r[i], p[i])[1,0] for i in range(12)]
sdev = np.array(np.append(sdevr[0], sdevp))
crmsd = np.array(np.append(0, crmsd))
ccoef = np.array(np.append(1, ccoef))
bias = np.append(0,bias)
ratio = np.append(1,ratio)
print(levlabel[lev], sdev[0],crmsd[0], ccoef[0])
print(np.size(r[0]))

# %%
######     BRISA MARINA   ######
xnames=['SB_'+levlabel[lev]]+expnames
media = np.array(np.append(rm[lev], pm))
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
print ('BRISA MARINA NIVEL '+levlabel[lev])
pd.DataFrame([media,ccoef,sdev,bias,ratio], columns=xnames, index=['m_sb'+levlabel[lev],'ccoef','sdev','bias','ratio'])

# %%
######    LOW LEVEL JET    #####
sodmsk = ma.masked_invalid(llj) 
inv = sodmsk.mask
idx = ~inv
sodmsk.shape

p = [eval(str(i)+'[indl,lev][idx[:,lev]]') for i in expnames]
pm = [np.mean(p[i]) for i in range(12)] 
r = [sodmsk[:,lev][idx[:,lev]].data for i in range(12)]
rm = [np.mean(r[i]) for i in range(12)]
p_pm = [(p[i] - pm[i]) for i in range(12)]
r_rm = [(r[i] - rm[i]) for i in range(12)]
crmsd = [np.sqrt(np.average(np.square((p_pm[i]) - (r_rm[i])))) for i in range(12)]
sdevp = [np.std(p[i]) for i in range(12)]
sdevr = [np.std(r[i]) for i in range(12)]
#  ratio:  Case_Variance/Reference_Variance
ratio = [(np.var(p[i]) / np.var(r[i])) for i in range(12)]
bias = [(np.average(p[i]) - np.average(r[i])) for i in range(12)]
sdev = [[sdevr[i], sdevp[i]] for i in range(12)];
ccoef =[ np.corrcoef(r[i], p[i])[1,0] for i in range(12)]
sdev = np.array(np.append(sdevr[0], sdevp))
crmsd = np.array(np.append(0, crmsd))
ccoef = np.array(np.append(1, ccoef))
bias = np.append(0,bias)
ratio = np.append(1,ratio)
print(expnames[0]+levlabel[lev], sdev[0], crmsd[0], ccoef[0])
print(np.size(r[0]))

# %%
######    LOW LEVEL JET    #####
for i in range(12):
    xnames=['LLJ_'+levlabel[lev]]+expnames
media = np.array(np.append(rm[0], pm))
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
print ('JET NOCTURNO NIVEL '+levlabel[lev])
#pd.DataFrame([media,bias,sdev,ratio,ccoef], columns=xnames, index=['media','bias','sdev','ratio','ccoef'])
pd.DataFrame([media,ccoef,sdev,bias,ratio], columns=xnames, index=['m_ll'+levlabel[lev],'ccoef','sdev','bias','ratio'])

# %% [markdown]
# http://www.ncl.ucar.edu/Applications/Scripts/taylor_stats.ncl
#   wsum    = sum(tw)                          ; sum of weights
#
#        tdiff   = t-tmean                          ; diff from 'test' weighted centered mean
#        rdiff   = r-rmean                          ;           'reference'
#        tvar    = sum(tw*tdiff^2)/wsum             ; mean area wgted difference: SUM[wgt*tdiff^2]/SUM[wgt]
#        rvar    = sum(tw*rdiff^2)/wsum
#        rmse    = wgt_arearmse(t,r, w, 1.0, 0)     ; area weighted individual grid point differences
#
#   else                                            ; CURVILINEAR GRID: w[*][*]
#        tmean   = wgt_areaave2(t, w, 1)            ; area weighted means
#        rmean   = wgt_areaave2(r, w, 1)
#
#        wsum    = sum(w)
#
#        tdiff   = t-tmean                          ; difference from central weighted mean
#        rdiff   = r-rmean                          ;    "        "      "       "      "
#        tvar    = sum(w*(tdiff^2))/wsum            ; mean area wgted difference: SUM[wgt*tdiff^2]/SUM[wgt]
#        rvar    = sum(w*(rdiff^2))/wsum            ;
#        rmse    = wgt_arearmse2(t,r, w, 0)         ; area weighted individual grid-point differences
#   end if
#
#   bias    = tmean-rmean                           ; test - reference
#   if (rmean.ne.0) then
#       bias = (bias/rmean)*100                     ; bias [%]
#   else
#       bias = totype(-999, typeof(bias))
#       bias@_FillValue = bias
#   end if
#   bias@long_name = "bias: [(tmean-rmean)/rmean]*100"
#   bias@units     = "%"
#
#   if (rvar.ne.0) then
#       ratio  = sqrt(tvar/rvar)
#   else
#       ratio = totype(-999, typeof(ratio))
#       ratio@_FillValue = ratio
#   end if
#   ratio@long_name = "RATIO: Taylor Diagram"
