# %%
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import numpy as np
expruns = ['20120816_d03_gfs05_p1r1', '20120816_d03_gfs05_p1r3','20120816_d03_gfs05_p1r5',
           '20120816_d03_gfs05_p2r1', '20120816_d03_gfs05_p2r3','20120816_d03_gfs05_p2r5',
           '20120816_d03_nam32_p1r1', '20120816_d03_nam32_p1r3','20120816_d03_nam32_p1r5',
           '20120816_d03_nam32_p2r1', '20120816_d03_nam32_p2r3','20120816_d03_nam32_p2r5']
expnames = ['g1r1', 'g1r3', 'g1r5', 'g2r1', 'g2r3', 'g2r5', 
            'n1r1', 'n1r3', 'n1r5', 'n2r1', 'n2r3', 'n2r5']
expruns[1]
# Out:
# '20120816_d03_gfs05_p1r3'

# %%
# READ WRF INTERP DATA
ids = [0,1,2,7,12,17,22,27,32,37,42,47]
t1, t2, t3, t4 = '2012-08-16 12:00', '2012-08-17 12:00', '2012-08-18 12:00', '2012-08-19 12:00'

wrf1  = xr.open_dataset('interp30/sodar_g1r1.nc')['uv30'].values
wrf2  = xr.open_dataset('interp30/sodar_g1r3.nc')['uv30'].values
wrf3  = xr.open_dataset('interp30/sodar_g1r5.nc')['uv30'].values
wrf4  = xr.open_dataset('interp30/sodar_g2r1.nc')['uv30'].values
wrf5  = xr.open_dataset('interp30/sodar_g2r3.nc')['uv30'].values
wrf6  = xr.open_dataset('interp30/sodar_g2r5.nc')['uv30'].values
wrf7  = xr.open_dataset('interp30/sodar_n1r1.nc')['uv30'].values
wrf8  = xr.open_dataset('interp30/sodar_n1r3.nc')['uv30'].values
wrf9  = xr.open_dataset('interp30/sodar_n1r5.nc')['uv30'].values
wrf10 = xr.open_dataset('interp30/sodar_n2r1.nc')['uv30'].values
wrf11 = xr.open_dataset('interp30/sodar_n2r3.nc')['uv30'].values
wrf12 = xr.open_dataset('interp30/sodar_n2r5.nc')['uv30'].values

drw1 = xr.open_dataset('interp30/sodar_g1r1.nc')['wd30'].values
drw2 = xr.open_dataset('interp30/sodar_g1r3.nc')['wd30'].values
drw3 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].values
drw4 = xr.open_dataset('interp30/sodar_g2r1.nc')['wd30'].values
drw5 = xr.open_dataset('interp30/sodar_g2r3.nc')['wd30'].values
drw6 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].values
drw7 = xr.open_dataset('interp30/sodar_n1r1.nc')['wd30'].values
drw8 = xr.open_dataset('interp30/sodar_n1r3.nc')['wd30'].values

tv1 = xr.open_dataset('interp30/sodar_g1r1.nc')['tv30'].values
tv2 = xr.open_dataset('interp30/sodar_g1r3.nc')['tv30'].values
tv3 = xr.open_dataset('interp30/sodar_g1r5.nc')['tv30'].values
tv4 = xr.open_dataset('interp30/sodar_g2r1.nc')['tv30'].values
tv5 = xr.open_dataset('interp30/sodar_g2r3.nc')['tv30'].values
tv6 = xr.open_dataset('interp30/sodar_g1r5.nc')['tv30'].values
tv7 = xr.open_dataset('interp30/sodar_n1r1.nc')['tv30'].values
tv8 = xr.open_dataset('interp30/sodar_n1r3.nc')['tv30'].values

sread_w =  pd.read_pickle('sodar_sp.pk')
sread_d =  pd.read_pickle('sodar_dd.pk')
sread_t =  pd.read_pickle('sodar_tv.pk')

sodarw =  sread_w.iloc[:,ids][t1:t4].interpolate().values
sodard =  sread_d.iloc[:,ids][t1:t4].interpolate().values
sodart =  sread_t.iloc[:,ids][t1:t4].interpolate().values

x1 = sread_w.iloc[:,ids][t1:t2].index
x2 = sread_w.iloc[:,ids][t2:t3].index
x3 = sread_w.iloc[:,ids][t3:t4].index

sodarw1 = sread_w.iloc[:,ids][t1:t2].interpolate().values
sodarw2 = sread_w.iloc[:,ids][t2:t3].interpolate().values
sodarw3 = sread_w.iloc[:,ids][t3:t4].interpolate().values
sodart1 = sread_t.iloc[:,ids][t1:t2].interpolate().values
sodart2 = sread_t.iloc[:,ids][t2:t3].interpolate().values
sodart3 = sread_t.iloc[:,ids][t3:t4].interpolate().values

# %%
print(wrf1.shape, sodarw.shape)
# Out:
# (145, 12) (145, 12)

# %%
def vstats(p,r):
    rm = np.ma.masked_invalid(r)
    rm[rm.mask] = 0
    p[rm.mask] = 0
    rmean = np.mean(rm, axis=0)
    pmean = np.mean(p, axis=0)
    rmax = np.max(rm, axis=0)
    pmax = np.max(p, axis=0)
    rstd = np.nanstd(rm, axis=0)
    pstd = np.nanstd(p, axis=0)
    bias = pmean - rmean
    '''
    Calculates the centered root-mean-square (RMS) difference between 
    two variables PREDICTED and REFERENCE (E'). The latter is calculated 
    using the formula:
    (E')^2 = sum_(n=1)^N [(p_n - mean(p))(r_n - mean(r))]^2/N
    where p is the predicted values, r is the reference values, and
    N is the total number of values in p & r. Note that p & r must
    have the same number of values.   
    '''
    crmsd = np.square((p - pmean) - (rm - rmean))
    crmsd = np.sum(crmsd, axis=0)/(p.size/12)
    crmsd = np.sqrt(crmsd)
    crmsd = crmsd.data
    corrp = np.ma.corrcoef(p,rm)[1,0]
    
    return pmean, rmean, bias, pmax, rmax, rstd, pstd, crmsd

# %%
i = 0
l, c = 11, 11
p = eval('wrf'+str(i+1))[:,:c]
p.shape
# Out:
# (145, 11)

# %%
pmean, rmean, bias, pmax, rmax, rstd, pstd, crmsd = {}, {}, {}, {}, {}, {}, {}, {}
corrp, rmsd = {}, {}

tt1, tt2, ll = 24, 120, 12
r = sodarw[tt1:tt2,:ll]
i, j = 0, 0

for i in range(12):
    corrp[i], rmsd[i] = {}, {}
    p = eval('wrf'+str(i+1))[tt1:tt2,:ll]
    pmean[i], rmean[i], bias[i], pmax[i], rmax[i], rstd[i], pstd[i], crmsd[i] = vstats(p, r)
    for j in range(12):
        pj = p[:,j]
        rj = r[:,j]
        corrp[i][j] = np.corrcoef(pj, rj)[0,1]
        rmsd[i][j]  = np.sqrt(np.sum(np.square(pj - rj))/len(pj))
    #print(corrp)
    #print(i)

# %%
pmean
# Out:
# {0: array([2.6248674, 2.7033768, 2.7817805, 3.078087 , 3.204361 , 3.2225962,
#         3.19928  , 3.1837606, 3.1777694, 3.1815422, 3.203235 , 3.2448828],
#        dtype=float32),
#  1: array([2.8084805, 2.922527 , 3.0364215, 3.480294 , 3.7076156, 3.8051014,
#         3.824749 , 3.7992337, 3.7512767, 3.6843088, 3.6003544, 3.506544 ],
#        dtype=float32),
#  2: array([2.5763214, 2.652495 , 2.7285664, 3.0306644, 3.1747675, 3.187505 ,
#         3.12714  , 3.0526056, 2.9794989, 2.9201815, 2.8918765, 2.897712 ],
#        dtype=float32),
#  3: array([2.7276838, 2.8329394, 2.938054 , 3.3619547, 3.6017046, 3.670563 ,
#         3.6131084, 3.5496082, 3.5163403, 3.5031633, 3.4994524, 3.4622848],
#        dtype=float32),
#  4: array([3.042039 , 3.15896  , 3.2757235, 3.752386 , 4.0853047, 4.3593364,
#         4.558661 , 4.657098 , 4.633012 , 4.493438 , 4.270655 , 3.9909022],
#        dtype=float32),
#  5: array([2.8727217, 2.9690936, 3.065336 , 3.4268968, 3.5967617, 3.6449602,
# ...

# %%
rm = pd.DataFrame(data=rmean )
pm = pd.DataFrame(data=pmean )
bs = pd.DataFrame(data=bias )
ps = pd.DataFrame(data=pstd )
pc = pd.DataFrame(data=corrp )
pr = pd.DataFrame(data=rmsd )

# %%
rm.iloc[3,0]
# Out:
# 4.678229166666667

# %%
import pandas as pd
d = {'Exp': expnames, 'Fcst mean': pm.iloc[3,:], 'bias': bs.iloc[3,:], 'STD': ps.iloc[3,:]
    , 'R': pc.iloc[3,:], 'RMSE': pr.iloc[3,:]}
df = pd.DataFrame(data=d )
print('ref mean =', rm.iloc[3,0])
df
# Out:
# ref mean = 4.678229166666667
#      Exp      mean      bias       STD         R      RMSE
# 0   g1r1  3.078087 -1.600142  2.252910  0.474880  3.173915
# 1   g1r3  3.480294 -1.197935  2.228464  0.621991  2.639151
# 2   g1r5  3.030664 -1.647565  2.261523  0.503298  3.140318
# 3   g2r1  3.361955 -1.316274  2.493262  0.505776  3.042024
# 4   g2r3  3.752386 -0.925843  2.541905  0.524960  2.861597
# 5   g2r5  3.426897 -1.251332  2.533495  0.510267  3.016855
# 6   n1r1  2.613662 -2.064567  2.017207  0.275724  3.716555
# 7   n1r3  3.249624 -1.428605  2.252115  0.345002  3.359455
# 8   n1r5  2.741456 -1.936773  2.206752  0.389945  3.506985
# 9   n2r1  3.191184 -1.487045  2.598985  0.476465  3.225762
# 10  n2r3  3.610658 -1.067571  2.241305  0.395931  3.111578
# 11  n2r5  3.302017 -1.376212  2.428342  0.417422  3.249858

# %%
corrp

# %%
bias

# %%
pstd

# %%
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
smean = np.nanmean(sodarw, axis=0)

plt.figure(figsize=(12,9) )

plt.plot(rmean[0], levels, label='sodar', marker="^")
plt.plot(pmean[0], levels, label=expnames[0]  , linestyle='--', marker="o")
plt.plot(pmean[1], levels, label=expnames[1]  , linestyle='--', marker="o")
plt.plot(pmean[2], levels, label=expnames[2]  , linestyle='--', marker="o")
plt.plot(pmean[3], levels, label=expnames[3]  , linestyle='--', marker="s")
plt.plot(pmean[4], levels, label=expnames[4]  , linestyle='--', marker="s")
plt.plot(pmean[5], levels, label=expnames[5]  , linestyle='--', marker="s")
plt.plot(pmean[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(pmean[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(pmean[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(pmean[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(pmean[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(pmean[11], levels, label=expnames[11], linestyle='-', marker="s")

plt.title('MEAN SPEED')

plt.xlabel('speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()
plt.savefig('figs/vert_mean') # m 1-g2r3 10-n2r3 7-n1r1

# %%
plt.figure(figsize=(12,9) )

plt.plot(rstd[0], levels, label='sodar', marker="^")
plt.plot(pstd[0], levels, label=expnames[0]  , linestyle='--', marker="o")
plt.plot(pstd[1], levels, label=expnames[1]  , linestyle='--', marker="o")
plt.plot(pstd[2], levels, label=expnames[2]  , linestyle='--', marker="o")
plt.plot(pstd[3], levels, label=expnames[3]  , linestyle='--', marker="s")
plt.plot(pstd[4], levels, label=expnames[4]  , linestyle='--', marker="s")
plt.plot(pstd[5], levels, label=expnames[5]  , linestyle='--', marker="s")
plt.plot(pstd[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(pstd[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(pstd[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(pstd[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(pstd[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(pstd[11], levels, label=expnames[11], linestyle='-', marker="s")

plt.title('STD DEV ')

plt.xlabel('speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()
plt.savefig('figs/vert_mean') # m 1-g2r3 10-n2r3 7-n1r1

# %%
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
smean = np.nanmean(sodarw, axis=0)

plt.figure(figsize=(12,9) )

#plt.plot(rmean[0], levels, label='sodar', marker="^")
plt.plot(bias[0], levels, label=expnames[0]  , linestyle='--', marker="o")
plt.plot(bias[1], levels, label=expnames[1]  , linestyle='--', marker="o")
plt.plot(bias[2], levels, label=expnames[2]  , linestyle='--', marker="o")
plt.plot(bias[3], levels, label=expnames[3]  , linestyle='--', marker="s")
plt.plot(bias[4], levels, label=expnames[4]  , linestyle='--', marker="s")
plt.plot(bias[5], levels, label=expnames[5]  , linestyle='--', marker="s")
plt.plot(bias[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(bias[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(bias[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(bias[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(bias[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(bias[11], levels, label=expnames[11], linestyle='-', marker="s")

plt.title('BIAS SPEED')

plt.xlabel('speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()
plt.savefig('figs/vert_mean') # m 1-g2r3 10-n2r3 7-n1r1

# %%
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
smean = np.nanmean(sodarw, axis=0)

plt.figure(figsize=(12,9) )

plt.plot(rmean[0], levels, label='sodar', marker="^")
plt.plot(pmean[0], levels, label=expnames[0]  , linestyle='--', marker="o")
plt.plot(pmean[1], levels, label=expnames[1]  , linestyle='--', marker="o")
plt.plot(pmean[2], levels, label=expnames[2]  , linestyle='--', marker="o")
plt.plot(pmean[3], levels, label=expnames[3]  , linestyle='--', marker="s")
plt.plot(pmean[4], levels, label=expnames[4]  , linestyle='--', marker="s")
plt.plot(pmean[5], levels, label=expnames[5]  , linestyle='--', marker="s")
plt.plot(pmean[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(pmean[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(pmean[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(pmean[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(pmean[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(pmean[11], levels, label=expnames[11], linestyle='-', marker="s")

plt.title('MEAN SPEED')

plt.xlabel('speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()
plt.savefig('figs/vert_mean') # m 1-g2r3 10-n2r3 7-n1r1

# %%
plt.figure(figsize=(12,9) )
# list(rmax.values())

plt.plot(rmax[0], levels, label='sodar', marker="^")
plt.plot(pmax[0], levels, label=expnames[0]  , linestyle='--', marker="o") 
plt.plot(pmax[1], levels, label=expnames[1]  , linestyle='--', marker="o") 
plt.plot(pmax[2], levels, label=expnames[2]  , linestyle='--', marker="o") 
plt.plot(pmax[3], levels, label=expnames[3]  , linestyle='--', marker="s") 
plt.plot(pmax[4], levels, label=expnames[4]  , linestyle='--', marker="s") 
plt.plot(pmax[5], levels, label=expnames[5]  , linestyle='--', marker="s") 
plt.plot(pmax[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(pmax[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(pmax[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(pmax[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(pmax[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(pmax[11], levels, label=expnames[11], linestyle='-', marker="s")
plt.title('MAX SPEED')


plt.legend()
plt.grid()
plt.xlabel('speed m/s')
plt.ylabel('meters AGL')
plt.savefig('figs/vert_max') # max 3-g2r1 15-n2r5 5-g2r5 6-n1r1

# %%
plt.figure(figsize=(12,9) )

plt.plot(rstd[0], levels, label='sodar rms', marker="^")
plt.plot(crmsd[0], levels, label=expnames[0]  , linestyle='--', marker="o")
plt.plot(crmsd[1], levels, label=expnames[1]  , linestyle='--', marker="o")
plt.plot(crmsd[2], levels, label=expnames[2]  , linestyle='--', marker="o")
plt.plot(crmsd[3], levels, label=expnames[3]  , linestyle='--', marker="s")
plt.plot(crmsd[4], levels, label=expnames[4]  , linestyle='--', marker="s")
plt.plot(crmsd[5], levels, label=expnames[5]  , linestyle='--', marker="s")
plt.plot(crmsd[6], levels, label=expnames[6]  , linestyle='-', marker="o") 
plt.plot(crmsd[7], levels, label=expnames[7]  , linestyle='-', marker="o")
plt.plot(crmsd[8], levels, label=expnames[8]  , linestyle='-', marker="o")
plt.plot(crmsd[9], levels, label=expnames[9]  , linestyle='-', marker="s")
plt.plot(crmsd[10], levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(crmsd[11], levels, label=expnames[11], linestyle='-', marker="s")

plt.title('CRMSD')

plt.legend()
plt.grid()
plt.xlabel('centered RMS deviation')
plt.ylabel('meters AGL')
plt.savefig('figs/vert_crmsd') # crmsd 1-g1r3 4-g2r3 3-g2r1

# %%
#list(d.values())

list(corrp[0].values())

# %%
plt.figure(figsize=(12,9) )

plt.plot(list(corrp[0].values()), levels, label=expnames[0] , linestyle='--', marker="o")
plt.plot(list(corrp[0].values()), levels, label=expnames[0] , linestyle='--', marker="o")
plt.plot(list(corrp[1].values()), levels, label=expnames[1] , linestyle='--', marker="o")
plt.plot(list(corrp[2].values()), levels, label=expnames[2] , linestyle='--', marker="o")
plt.plot(list(corrp[3].values()), levels, label=expnames[3] , linestyle='--', marker="s")
plt.plot(list(corrp[4].values()), levels, label=expnames[4] , linestyle='--', marker="s")
plt.plot(list(corrp[5].values()), levels, label=expnames[5] , linestyle='--', marker="s")
plt.plot(list(corrp[6].values()), levels, label=expnames[6] , linestyle='-', marker="o") 
plt.plot(list(corrp[7].values()), levels, label=expnames[7] , linestyle='-', marker="o")
plt.plot(list(corrp[8].values()), levels, label=expnames[8] , linestyle='-', marker="o")
plt.plot(list(corrp[9].values()), levels, label=expnames[9] , linestyle='-', marker="s")
plt.plot(list(corrp[10].values()), levels, label=expnames[10], linestyle='-', marker="s")
plt.plot(list(corrp[11].values()), levels, label=expnames[11], linestyle='-', marker="s")

plt.title('R PEARSON')

plt.legend()
plt.grid()
plt.xlabel('Correlation R')
plt.ylabel('meters AGL')
plt.savefig('figs/vert_corr') # R 2-g1r5 4-g2r3 7-n1r1 3-g2r1

# %%
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
smean = np.nanmean(sodarw, axis=0)

plt.figure(figsize=(12,9) )
plt.plot(rmean[0], levels, label='sodar', marker="^")
plt.title(' RMSE ')
plt.xlabel(' RMSE ')
plt.ylabel('meters AGL')
plt.grid()
for i in range(12):
    plt.plot(list(rmsd[i]), levels, label=expnames[0]  , linestyle='--', marker="o")

# %%
import matplotlib.pyplot as plt
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
plt.figure(figsize=(15,11) )
 
plt.suptitle('Experiments results from NAM & GFS models and PBL 1 & 2', fontsize=16)
# m 1-g2r3 10-n2r3 7-n1r1
plt.subplot(221)
plt.title('MEAN SPEED')
plt.plot(rmean[0],  levels, label='sodar', marker="s")
plt.plot(pmean[1],  levels, label=expnames[1], marker="o")
plt.plot(pmean[10], levels, label=expnames[10], marker="^")
plt.plot(pmean[7],  levels, label=expnames[7], marker="x")
plt.xticks(np.arange(2,9,1))
plt.xlabel('Speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()

 # max 3-g2r1 11-n2r5 5-g2r5 6-n1r1 
plt.subplot(222)
plt.title('MAX SPEED')
plt.plot(rmax[0],  levels, label='sodar', marker="s")
plt.plot(pmax[3],  levels, label=expnames[3], marker="o")
plt.plot(pmax[11], levels, label=expnames[11], marker="^")
plt.plot(pmax[6],  levels, label=expnames[6], marker="x")
plt.xticks(np.arange(4,15,2))
plt.xlabel('Speed m/s')
plt.legend()
plt.grid()

# crmsd 1-g1r3 4-g2r3 3-g2r1
plt.subplot(223)
plt.title('CRMSD')
plt.plot(rstd[0] , levels, label='sodar rms', marker="s")
plt.plot(crmsd[1], levels, label=expnames[1], marker="o")
plt.plot(crmsd[4], levels, label=expnames[4], marker="^")
plt.plot(crmsd[3], levels, label=expnames[3], marker="x")
plt.xticks(np.arange(2,4.5,0.5))
plt.ylabel('meters AGL')
plt.xlabel('Centered RMSD')
plt.legend()
plt.grid()

# R 2-g1r5 4-g2r3 7-n1r1 3-g2r1
plt.subplot(224)
plt.title('R PEARSON')
#plt.plot(g2s['COV'], levels, label='COV', marker="s")
plt.plot(list(corrp[2].values()), levels, label=expnames[2], marker="s")
plt.plot(list(corrp[4].values()), levels, label=expnames[4], marker="o")
plt.plot(list(corrp[7].values()), levels, label=expnames[7], marker="^")
plt.plot(list(corrp[3].values()), levels, label=expnames[3], marker="x")
plt.xticks(np.arange(0,1.1,0.2))
plt.xlabel('Correlation Coeff')


plt.legend()
plt.grid()

plt.show()
plt.savefig('figs/vert_best')

# %%
import matplotlib.pyplot as plt
levels = [30, 40, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
plt.figure(figsize=(15,11) )
 
plt.suptitle('Experiments results from NAM & GFS models and PBL 1 & 2', fontsize=16)
# m 1-g2r3 10-n2r3 7-n1r1
plt.subplot(221)
plt.title('MEAN SPEED')
plt.plot(rmean[0],  levels, label='sodar', marker="s")
plt.plot(pmean[1],  levels, label=expnames[1], marker="o")
plt.plot(pmean[10], levels, label=expnames[10], marker="^")
plt.plot(pmean[7],  levels, label=expnames[7], marker="x")
plt.xticks(np.arange(2,9,1))
plt.xlabel('Speed m/s')
plt.ylabel('meters AGL')
plt.legend()
plt.grid()

 # max 3-g2r1 11-n2r5 5-g2r5 6-n1r1 
plt.subplot(222)
plt.title('MAX SPEED')
plt.plot(rmax[0],  levels, label='sodar', marker="s")
plt.plot(pmax[3],  levels, label=expnames[3], marker="o")
plt.plot(pmax[11], levels, label=expnames[11], marker="^")
plt.plot(pmax[6],  levels, label=expnames[6], marker="x")
plt.xticks(np.arange(4,15,2))
plt.xlabel('Speed m/s')
plt.legend()
plt.grid()

# crmsd 1-g1r3 4-g2r3 3-g2r1
plt.subplot(223)
plt.title('CRMSD')
plt.plot(rstd[0] , levels, label='sodar rms', marker="s")
plt.plot(crmsd[1], levels, label=expnames[1], marker="o")
plt.plot(crmsd[4], levels, label=expnames[4], marker="^")
plt.plot(crmsd[3], levels, label=expnames[3], marker="x")
plt.xticks(np.arange(2,4.5,0.5))
plt.ylabel('meters AGL')
plt.xlabel('Centered RMSD')
plt.legend()
plt.grid()

# R 2-g1r5 4-g2r3 7-n1r1 3-g2r1
plt.subplot(224)
plt.title('R PEARSON')
#plt.plot(g2s['COV'], levels, label='COV', marker="s")
plt.plot(list(corrp[2].values()), levels, label=expnames[2], marker="s")
plt.plot(list(corrp[4].values()), levels, label=expnames[4], marker="o")
plt.plot(list(corrp[7].values()), levels, label=expnames[7], marker="^")
plt.plot(list(corrp[3].values()), levels, label=expnames[3], marker="x")
plt.xticks(np.arange(0,1.1,0.2))
plt.xlabel('Correlation Coeff')


plt.legend()
plt.grid()

plt.show()
plt.savefig('figs/vert_best')
