# %%
ls

#../../../../namanl_201303/namanl_218_20130301_0000_000.grb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-6fc25377d513> in <module>()
# ----> 1 ls
#       2
#       3 #../../../../namanl_201303/namanl_218_20130301_0000_000.grb
#
# NameError: name 'ls' is not defined

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
ds1 = Dataset('30s_geo_em.d01.nc')
ds2 = Dataset('30s_geo_em.d02.nc')
ds3 = Dataset('30s_geo_em.d03.nc')

print (ds1.file_format)
#print (dataset1.dimensions.keys())
#print (dataset1.variables.keys())
# Out:
# NETCDF3_64BIT_OFFSET

# %%
list(ds1.dimensions.keys())
# Out:
# ['Time',
#  'DateStrLen',
#  'west_east',
#  'south_north',
#  'south_north_stag',
#  'west_east_stag',
#  'land_cat',
#  'soil_cat',
#  'month',
#  'num_urb_params']

# %%
ds1.variables.keys()
# Out:
# odict_keys(['Times', 'XLAT_M', 'XLONG_M', 'XLAT_V', 'XLONG_V', 'XLAT_U', 'XLONG_U', 'CLAT', 'CLONG', 'MAPFAC_M', 'MAPFAC_V', 'MAPFAC_U', 'MAPFAC_MX', 'MAPFAC_VX', 'MAPFAC_UX', 'MAPFAC_MY', 'MAPFAC_VY', 'MAPFAC_UY', 'E', 'F', 'SINALPHA', 'COSALPHA', 'LANDMASK', 'XLAT_C', 'XLONG_C', 'SINALPHA_U', 'COSALPHA_U', 'SINALPHA_V', 'COSALPHA_V', 'LANDUSEF', 'LU_INDEX', 'HGT_M', 'SOILTEMP', 'SOILCTOP', 'SCT_DOM', 'SOILCBOT', 'SCB_DOM', 'ALBEDO12M', 'GREENFRAC', 'LAI12M', 'SNOALB', 'SLOPECAT', 'CON', 'VAR', 'OA1', 'OA2', 'OA3', 'OA4', 'OL1', 'OL2', 'OL3', 'OL4', 'VAR_SSO', 'LAKE_DEPTH', 'URB_PARAM'])

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from mpl_toolkits.basemap import Basemap

from wrf import to_np, getvar, smooth2d, get_basemap, latlon_coords

# Open the NetCDF file
d0330s = Dataset('30s_geo_em.d03.nc')
d031m = Dataset('1m_geo_em.d03.nc')

# Get the sea level pressure
ter = getvar(d031m, "ter")

# Smooth the sea level pressure since it tends to be noisy near the mountains
ter_hgt = smooth2d(slp, 3)

# Get the latitude and longitude points
lats, lons = latlon_coords(ter)

# Get the basemap object
bm = get_basemap(ter)

# Create a figure
fig = plt.figure(figsize=(12,9))

# Add geographic outlines
bm.drawcoastlines(linewidth=0.25)
bm.drawstates(linewidth=0.25)
bm.drawcountries(linewidth=0.25)

# Convert the lats and lons to x and y.  Make sure you convert the lats and lons to
# numpy arrays via to_np, or basemap crashes with an undefined RuntimeError.
x, y = bm(to_np(lons), to_np(lats))

# Draw the contours and filled contours
bm.contour(x, y, to_np(ter), 10, colors="black")
bm.contourf(x, y, to_np(ter), 10, cmap=get_cmap("jet"))

# Add a color bar
plt.colorbar()    #shrink=.9

plt.title("Terrain Height d03 1m geogrid")
plt.savefig('Terrain1m_geogrid.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-94d2f6f4abf1> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib.cm import get_cmap
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5
#       6 from wrf import to_np, getvar, smooth2d, get_basemap, latlon_coords
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
# ../../../../namanl_201303/namanl_218_20130301_0000_000.grb
# http://wrf-python.readthedocs.io/en/latest/user_api/generated/wrf.getvar.html#wrf.getvar
    
# Open the NetCDF file
ncfile = Dataset('../../../../WRFV3/run/wrfout_d03_2013-03-01_00:00:00')

# Get the sea level pressure
ter = getvar(ncfile, "ter")

# Smooth the sea level pressure since it tends to be noisy near the mountains
# ter_hgt = smooth2d(slp, 3)

# Get the latitude and longitude points
lats, lons = latlon_coords(ter)

# Get the basemap object
bm = get_basemap(ter)

# Create a figure
fig = plt.figure(figsize=(12,9))

# Add geographic outlines
bm.drawcoastlines(linewidth=0.25)
bm.drawstates(linewidth=0.25)
bm.drawcountries(linewidth=0.25)

# Convert the lats and lons to x and y.  Make sure you convert the lats and lons to
# numpy arrays via to_np, or basemap crashes with an undefined RuntimeError.
x, y = bm(to_np(lons), to_np(lats))

# Draw the contours and filled contours
bm.contour(x, y, to_np(ter), 10, colors="black")
bm.contourf(x, y, to_np(ter), 10, cmap=get_cmap("jet"))

# Add a color bar
plt.colorbar()    #shrink=.9

plt.title("Terrain Height d03 WRF")
plt.savefig('TerrainWRF.png')
plt.show()
# Out:
# /home/wrf/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3505: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wrf/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3572: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/wrf/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wrf/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
ter.shape
# Out:
# (29, 29)
