# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# ds083  GFS    NAM
# 1deg   0.5deg  12km
# https://www.ncdc.noaa.gov/data-access/model-data/model-datasets/north-american-mesoscale-forecast-system-nam
# https://www.ncdc.noaa.gov/data-access/model-data/model-datasets/global-forcast-system-gfs

# %%
from netCDF4 import Dataset
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import wrf
from wrf import getvar, vinterp, ALL_TIMES, destagger, to_np, interplevel
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\xarray\core\merge.py:10: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
expruns = ['20120816_d03_gfs05_p1r1', '20120816_d03_gfs05_p1r3','20120816_d03_gfs05_p1r5',
           '20120816_d03_gfs05_p2r1', '20120816_d03_gfs05_p2r3','20120816_d03_gfs05_p2r5',
           '20120816_d03_nam32_p1r1', '20120816_d03_nam32_p1r3','20120816_d03_nam32_p1r5',
           '20120816_d03_nam32_p2r1', '20120816_d03_nam32_p2r3','20120816_d03_nam32_p2r5',
           ]
expnames = ['g1r1', 'g1r3', 'g1r5', 'g2r1', 'g2r3', 'g2r5', 
            'n1r1', 'n1r3', 'n1r5', 'n2r1', 'n2r3', 'n2r5']
expruns[1]
# Out:
# '20120816_d03_gfs05_p1r3'

# %%
#ls interp30\

# %%
# READ WRF INTERP DATA
ids = [0,1,2,7,12,17,22,27,32,37,42,47]
t1, t2, t3, t4 = '2012-08-16 12:30', '2012-08-17 12:00', '2012-08-18 12:00', '2012-08-19 12:00'
zlevels=['30','40','50','100','150','200','250','300','350','400','450','500']
wrf = xr.open_dataset('interp30/sodar_g1r1.nc')['uv30']
wrf1 = xr.open_dataset('interp30/sodar_g1r1.nc')['uv30'].values
wrf2 = xr.open_dataset('interp30/sodar_g1r3.nc')['uv30'].values
wrf3 = xr.open_dataset('interp30/sodar_g1r5.nc')['uv30'].values
wrf4 = xr.open_dataset('interp30/sodar_g2r1.nc')['uv30'].values
wrf5 = xr.open_dataset('interp30/sodar_g2r3.nc')['uv30'].values
wrf6 = xr.open_dataset('interp30/sodar_g2r5.nc')['uv30'].values
wrf7 = xr.open_dataset('interp30/sodar_n1r1.nc')['uv30'].values
wrf8 = xr.open_dataset('interp30/sodar_n1r3.nc')['uv30'].values
wrf9 = xr.open_dataset('interp30/sodar_n1r5.nc')['uv30'].values
wrf10= xr.open_dataset('interp30/sodar_n2r1.nc')['uv30'].values
wrf11= xr.open_dataset('interp30/sodar_n2r3.nc')['uv30'].values
wrf12= xr.open_dataset('interp30/sodar_n2r5.nc')['uv30'].values

drw1 = xr.open_dataset('interp30/sodar_g1r1.nc')['wd30'].values
drw2 = xr.open_dataset('interp30/sodar_g1r3.nc')['wd30'].values
drw3 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].values
drw4 = xr.open_dataset('interp30/sodar_g2r1.nc')['wd30'].values
drw5 = xr.open_dataset('interp30/sodar_g2r3.nc')['wd30'].values
drw6 = xr.open_dataset('interp30/sodar_g1r5.nc')['wd30'].values
drw7 = xr.open_dataset('interp30/sodar_n1r1.nc')['wd30'].values
drw8 = xr.open_dataset('interp30/sodar_n1r3.nc')['wd30'].values

tv1 = xr.open_dataset('interp30/sodar_g1r1.nc')['tv30'].values
tv2 = xr.open_dataset('interp30/sodar_g1r3.nc')['tv30'].values
tv3 = xr.open_dataset('interp30/sodar_g1r5.nc')['tv30'].values
tv4 = xr.open_dataset('interp30/sodar_g2r1.nc')['tv30'].values
tv5 = xr.open_dataset('interp30/sodar_g2r3.nc')['tv30'].values
tv6 = xr.open_dataset('interp30/sodar_g1r5.nc')['tv30'].values
tv7 = xr.open_dataset('interp30/sodar_n1r1.nc')['tv30'].values
tv8 = xr.open_dataset('interp30/sodar_n1r3.nc')['tv30'].values
tv9 = xr.open_dataset('interp30/sodar_n1r5.nc')['tv30'].values
tv10= xr.open_dataset('interp30/sodar_n2r1.nc')['tv30'].values
tv11= xr.open_dataset('interp30/sodar_n2r3.nc')['tv30'].values
tv12= xr.open_dataset('interp30/sodar_n2r5.nc')['tv30'].values


sread_w =  pd.read_pickle('sodar_sp.pk')
sread_d =  pd.read_pickle('sodar_dd.pk')
sread_t =  pd.read_pickle('sodar_tv.pk')

sodarw =  sread_w.iloc[:,ids][t1:t4].interpolate().values
sodard =  sread_d.iloc[:,ids][t1:t4].interpolate().values
sodart =  sread_t.iloc[:,ids][t1:t4].interpolate().values

x1 = sread_w.iloc[:,ids]['2012-08-16 12:30':'2012-08-17 12:00'].index
x2 = sread_w.iloc[:,ids]['2012-08-17 12:30':'2012-08-18 12:00'].index
x3 = sread_w.iloc[:,ids]['2012-08-18 12:30':'2012-08-19 12:00'].index

sodarw1 = sread_w.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodarw2 = sread_w.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values
sodarw3 = sread_w.iloc[:,ids]['2012-08-18 12:30':'2012-08-19 12:00'].interpolate().values
sodart1 = sread_t.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodart2 = sread_t.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values
sodart3 = sread_t.iloc[:,ids]['2012-08-18 12:30':'2012-08-19 12:00'].interpolate().values

# %%
#xr.open_dataset('interp30/sodar_g1r1.nc')['tv30']
wrf
# Out:
# <xarray.DataArray 'uv30' (Time: 145, interp_level: 12)>
# array([[1.976057, 1.998431, 2.020774, ..., 1.547575, 1.43124 , 1.318264],
#        [3.829608, 3.913747, 3.997773, ..., 3.944606, 3.841184, 3.729788],
#        [5.628348, 5.772418, 5.916296, ..., 5.880783, 5.711979, 5.531928],
#        ...,
#        [2.035292, 2.063964, 2.092597, ..., 1.921552, 1.910267, 1.926955],
#        [3.188793, 3.248305, 3.307739, ..., 2.996796, 2.881765, 2.765723],
#        [3.256968, 3.32536 , 3.393661, ..., 3.270134, 3.175171, 3.076385]],
#       dtype=float32)
# Coordinates:
#   * Time          (Time) datetime64[ns] 2012-08-16T12:00:00 ... 2012-08-19T12:00:00
#   * interp_level  (interp_level) float64 0.03 0.04 0.05 0.1 ... 0.4 0.45 0.5

# %%
def panelPlot(level):
    fig, axs = plt.subplots(2, 3, figsize=(12,7))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.3)
    for axl in range(0,2):
        for axc in range(0,3):
            plt.setp( axs[axl,axc].xaxis.get_majorticklabels(), rotation=25 )
            axs[0,0].set_ylabel('Wind Speed')
            axs[1,0].set_ylabel('Virtual Temperature')

    ax = axs[0, 0]
    ax.plot(x1, sodarw1[:,level], label='sodarW')
    ax.plot(x1, wrf1[t1:t2+1, level], label=expnames[1])
    ax.plot(x1, wrf2[t1:t2+1, level], label=expnames[2])
    ax.plot(x1, wrf3[t1:t2+1, level], label=expnames[3])
    ax.legend();

    ax = axs[0, 1]
    ax.plot(x2, sodarw2[:,level], label='sodarW')
    ax.plot(x2, wrf1[t2:t3+1, level], label=expnames[1])
    ax.plot(x2, wrf2[t2:t3+1, level], label=expnames[2])
    ax.plot(x2, wrf3[t2:t3+1, level], label=expnames[3])
    ax.legend();

    ax = axs[0, 2]
    ax.plot(x3, sodarw3[:,level], label='sodarW')
    ax.plot(x3, wrf1[t3:t4+1, level], label=expnames[1])
    ax.plot(x3, wrf2[t3:t4+1, level], label=expnames[2])
    ax.plot(x3, wrf3[t3:t4+1, level], label=expnames[3])
    ax.legend();

    ax = axs[1, 0]
    ax.plot(x1, sodart1[:,level],  label='sodarTV')
    ax.plot(x1, tv1[t1:t2+1, level], label=expnames[1])
    ax.plot(x1, tv2[t1:t2+1, level], label=expnames[2])
    ax.plot(x1, tv3[t1:t2+1, level], label=expnames[3])
    ax.legend();

    ax = axs[1, 1]
    ax.plot(x2, sodart2[:,level], label='sodarTV');
    ax.plot(x2, tv1[t2:t3+1, level], label=expnames[1])
    ax.plot(x2, tv2[t2:t3+1, level], label=expnames[2])
    ax.plot(x2, tv3[t2:t3+1, level], label=expnames[3])
    ax.legend();

    ax = axs[1, 2]
    ax.plot(x3, sodart3[:,level],  label='sodarTV');
    ax.plot(x3, tv1[t3:t4+1, level], label=expnames[1])
    ax.plot(x3, tv2[t3:t4+1, level], label=expnames[2])
    ax.plot(x3, tv3[t3:t4+1, level], label=expnames[3])
    ax.legend();
    #plt.suptitle('Wind Speed '+skey);
    #plt.savefig('figs/panelPlotd'+skey+'.png', dpi=300)

# %%
def panelPlot2(level):
    #skey = sodarw1.keys()[level*1000]
    #wkey = wrf1.interp_level.values*1000
    fig, axs = plt.subplots(2, 3, figsize=(15,9))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.15, hspace=0.3)
    for axl in range(0,2):
        for axc in range(0,3):
            plt.setp( axs[axl,axc].xaxis.get_majorticklabels(), rotation=25 )
            axs[0,0].set_ylabel('Wind Speed')
            axs[1,0].set_ylabel('Wind Speed')
    lw = 0.6
    ax = axs[0, 0]
    ax.set_ylim([0, 12])
    ax.plot(x1, sodarw1[:,level], label='sodarW')
    ax.plot(x1, wrf1[t1:t2+1, level], label=expnames[0], linewidth=lw)
    ax.plot(x1, wrf2[t1:t2+1, level], label=expnames[1], linewidth=lw)
    ax.plot(x1, wrf3[t1:t2+1, level], label=expnames[2], linewidth=lw)
    ax.plot(x1, wrf4[t1:t2+1, level], label=expnames[3], linewidth=lw)
    ax.legend();

    ax = axs[0, 1]
    ax.set_ylim([0, 12])
    ax.plot(x2, sodarw2[:,level], label='sodarW')
    ax.plot(x2, wrf1[t2:t3+1, level], label=expnames[0], linewidth=lw)
    ax.plot(x2, wrf2[t2:t3+1, level], label=expnames[1], linewidth=lw)
    ax.plot(x2, wrf3[t2:t3+1, level], label=expnames[2], linewidth=lw)
    ax.plot(x2, wrf4[t2:t3+1, level], label=expnames[3], linewidth=lw)
    ax.legend();

    ax = axs[0, 2]
    ax.set_ylim([0, 12])
    ax.plot(x3, sodarw3[:,level], label='sodarW')
    ax.plot(x3, wrf1[t3:t4+1, level], label=expnames[0], linewidth=lw)
    ax.plot(x3, wrf2[t3:t4+1, level], label=expnames[1], linewidth=lw)
    ax.plot(x3, wrf3[t3:t4+1, level], label=expnames[2], linewidth=lw)
    ax.plot(x3, wrf4[t3:t4+1, level], label=expnames[3], linewidth=lw)
    ax.legend();

    ax = axs[1, 0]
    ax.set_ylim([0, 12])
    ax.plot(x1, sodarw1[:,level], label='sodarW')
    ax.plot(x1, wrf5[t1:t2+1, level], label=expnames[4], linewidth=lw)
    ax.plot(x1, wrf6[t1:t2+1, level], label=expnames[5], linewidth=lw)
    ax.plot(x1, wrf7[t1:t2+1, level], label=expnames[6], linewidth=lw)
    ax.plot(x1, wrf8[t1:t2+1, level], label=expnames[7], linewidth=lw)
    ax.legend();

    ax = axs[1, 1]
    ax.set_ylim([0, 12])
    ax.plot(x2, sodarw2[:,level], label='sodarW')
    ax.plot(x2, wrf5[t2:t3+1, level], label=expnames[4], linewidth=lw)
    ax.plot(x2, wrf6[t2:t3+1, level], label=expnames[5], linewidth=lw)
    ax.plot(x2, wrf7[t2:t3+1, level], label=expnames[6], linewidth=lw)
    ax.plot(x2, wrf8[t2:t3+1, level], label=expnames[7], linewidth=lw)
    ax.legend();

    ax = axs[1, 2]
    ax.set_ylim([0, 12])
    ax.plot(x3, sodarw3[:,level], label='sodarW')
    ax.plot(x3, wrf5[t3:t4+1, level], label=expnames[4], linewidth=lw)
    ax.plot(x3, wrf6[t3:t4+1, level], label=expnames[5], linewidth=lw)
    ax.plot(x3, wrf7[t3:t4+1, level], label=expnames[6], linewidth=lw)
    ax.plot(x3, wrf8[t3:t4+1, level], label=expnames[7], linewidth=lw)
    ax.legend();

    plt.suptitle('Wind Speed ');
    #print(level, skey, wkey)
    #plt.savefig('figs/panelPlotd'+skey+'.png', dpi=300)

# %%
def ProfilesPanel1(tt):
    fig, axs = plt.subplots(1, 2, figsize=(13,8))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.2)
    axs[0].set_ylabel('m AGL')
    axs[0].set_xlabel('Wind Speed')
    axs[1].set_xlabel('Virtual Temperature')
    plot_levs = [30,40,50,100,150,200,250,300,350,400,450,500]
     
    ax = axs[0]
    ax.plot(sodarw[tt,:], plot_levs, label='SOD ', ls='solid', color='b')
    vdir = np.radians(sodard[tt,:])
    xx, uu, vv = sodarw[tt,:], np.sin(vdir), np.cos(vdir)
    ax.quiver(xx, plot_levs, uu, vv, pivot='mid', color='b')
    
    ax.plot(wrf1[tt,:], plot_levs, label=expnames[0], ls='-', color='0.2')
    ax.plot(wrf2[tt,:], plot_levs, label=expnames[1], ls='--', color='0.2')
    ax.plot(wrf3[tt,:], plot_levs, label=expnames[2], ls='-.', color='0.2')
    ax.plot(wrf4[tt,:], plot_levs, label=expnames[3], ls=':', color='0.2')
    ax.plot(wrf5[tt,:], plot_levs, label=expnames[4], ls='--', color='0.4')      
    ax.plot(wrf6[tt,:], plot_levs, label=expnames[5], ls='--', color='0.4')
    ax.plot(wrf7[tt,:], plot_levs, label=expnames[6], ls='-.', color='0.4')
    ax.plot(wrf8[tt,:], plot_levs, label=expnames[7], ls=':', color='0.4')
    ax.plot(wrf9[tt,:], plot_levs, label=expnames[8], ls='--', color='0.4')      
    ax.plot(wrf10[tt,:], plot_levs, label=expnames[9], ls='--', color='0.4')
    ax.plot(wrf11[tt,:], plot_levs, label=expnames[10], ls='-.', color='0.4')
    ax.plot(wrf12[tt,:], plot_levs, label=expnames[11], ls=':', color='0.4')
    vdir = np.radians(drw1[tt,:])
    ax.quiver(wrf1[tt,:], plot_levs, np.sin(vdir), np.cos(vdir), pivot='mid', color='0.4')        
    vdir = np.radians(drw4[tt,:])
    ax.quiver(wrf4[tt,:], plot_levs, np.sin(vdir), np.cos(vdir), pivot='mid', color='0.6')        
    vdir = np.radians(drw7[tt,:])
    ax.quiver(wrf7[tt,:], plot_levs, np.sin(vdir), np.cos(vdir), pivot='mid', color='0.8')        
    ax.legend()

    ax = axs[1]
    ax.plot(sodart[tt,:], plot_levs, label='SOD ', ls='solid', color='b')        
    ax.plot(tv1[tt,:], plot_levs, label=expnames[0], ls='-', color='0.2')
    ax.plot(tv2[tt,:], plot_levs, label=expnames[1], ls='--', color='0.2')
    ax.plot(tv3[tt,:], plot_levs, label=expnames[2], ls='-.', color='0.2')
    ax.plot(tv4[tt,:], plot_levs, label=expnames[3], ls=':', color='0.2')
    ax.plot(tv5[tt,:], plot_levs, label=expnames[4], ls='-', color='0.4')
    ax.plot(tv6[tt,:], plot_levs, label=expnames[5], ls='--', color='0.4')
    ax.plot(tv7[tt,:], plot_levs, label=expnames[6], ls='-.', color='0.4')
    ax.plot(tv8[tt,:], plot_levs, label=expnames[7], ls=':', color='0.4')
    ax.plot(tv9[tt,:], plot_levs, label=expnames[8], ls='-', color='0.4')
    ax.plot(tv10[tt,:], plot_levs, label=expnames[9], ls='--', color='0.4')
    ax.plot(tv11[tt,:], plot_levs, label=expnames[10], ls='-.', color='0.4')
    ax.plot(tv12[tt,:], plot_levs, label=expnames[11], ls=':', color='0.4')
    ax.legend()
    
    ts = sread_w.index[tt-1]
    ts = ts.strftime('%Y-%m-%d-%H:%M')
    
    plt.title('Vertical Profile '+str(ts), x=-0.10)
    #plt.ylabel(' m AGL ')
    #plt.xlabel(' Wind Speed ')
    #plt.savefig('ProfilesPanel_'+skey+'.png', dpi=300)

# %%
def ProfilesPanel2(tstart,tend,deltat,wrfrun):
    fig, axs = plt.subplots(1, 2, figsize=(12,7))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.3)
    axs[0].set_ylabel('m AGL')
    axs[1].set_ylabel('m AGL')
    axs[0].set_xlabel('Wind Speed')
    axs[1].set_xlabel('Virtual Temperature')
    plot_levs = [30,40,50,100,150,200,250,300,350,400,450,500]
    marker=['x', 'o', '^']
    color=['k','r','b','g']
    i=0
    for tt in np.arange(tstart,tend,deltat):
        ax = axs[0]
        #ts = eval('wrfrun.iloc[tt,:].name')
        #d = ts.strftime('d%d-%H:%M')
        ax.plot(wrf1[tt,:], plot_levs, label='WRF ', ls='dashed', color=color[i])
        #ax.quiver(wrf1.iloc[tt,:], plot_levs, -np.sin(vdir), -np.cos(vdir), pivot='mid', color='k')
        
        ax.plot(sodarw[tt,:], plot_levs, label='SOD ', ls='solid', color=color[i])
        #vdir = np.radians(drw1.iloc[tt,:])    
        #ax.quiver(sodarw.iloc[tt,:], plot_levs, -np.sin(vdir), -np.cos(vdir), pivot='mid', color='k')
        ax.legend()
        
        ax = axs[1]
        ax.plot(tv1[tt,:], plot_levs, label='WRF ', ls='dashed', color=color[i])
        ax.plot(sodart[tt,:], plot_levs, label='SOD ', ls='solid', color=color[i])        
        ax.legend()
        ts = sread_w.index[tt-1]
        ts = ts.strftime('%Y-%m-%d-%H:%M')
        plt.title(' Wind Profile '+str(ts), x=-0.10)
        
        i=i+1
    #plt.ylabel(' m AGL ')
    #plt.xlabel(' Wind Speed ')
    #plt.savefig('ProfilesPanel_'+skey+'.png', dpi=300)

# %%
x1 = sread_w.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].index
x2 = sread_w.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].index
sodarw1 = sread_w.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodarw2 = sread_w.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values
sodart1 = sread_t.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodart2 = sread_t.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values

def panelPlot3(level):
    #skey = sodarw1.keys()[level*1000]
    #wkey = wrf1.interp_level.values*1000
    fig, axs = plt.subplots(2, 2, figsize=(15,9))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.1, hspace=0.2)
    for axl in range(0,2):
        for axc in range(0,2):
            plt.setp( axs[axl,axc].xaxis.get_majorticklabels(), rotation=25 )
            axs[axl,axc].grid()
            axs[0,0].set_ylabel('Wind Speed')
            axs[1,0].set_ylabel('Wind Speed')
    lw = 0.6
    ax = axs[0, 0]
    ax.set_ylim([0, 12])
    ax.plot(x1, sodarw1[:,level], label='sodarW')
    ax.plot(x1, wrf1[t1:t2, level], label=expnames[0], linewidth=lw)
    ax.plot(x1, wrf2[t1:t2, level], label=expnames[1], linewidth=lw)
    ax.plot(x1, wrf3[t1:t2, level], label=expnames[2], linewidth=lw)
    ax.plot(x1, wrf4[t1:t2, level], label=expnames[3], linewidth=lw)
    ax.plot(x1, wrf5[t1:t2, level], label=expnames[4], linewidth=lw)
    ax.plot(x1, wrf6[t1:t2, level], label=expnames[5], linewidth=lw)
    ax.legend();

    ax = axs[0, 1]
    ax.set_ylim([0, 12])
    ax.plot(x2, sodarw2[:,level], label='sodarW')
    ax.plot(x2, wrf1[t2:t3, level], label=expnames[0], linewidth=lw)
    ax.plot(x2, wrf2[t2:t3, level], label=expnames[1], linewidth=lw)
    ax.plot(x2, wrf3[t2:t3, level], label=expnames[2], linewidth=lw)
    ax.plot(x2, wrf4[t2:t3, level], label=expnames[3], linewidth=lw)
    ax.plot(x2, wrf5[t2:t3, level], label=expnames[4], linewidth=lw)
    ax.plot(x2, wrf6[t2:t3, level], label=expnames[5], linewidth=lw)
    ax.legend();

    #ax = axs[0, 2]
    #ax.set_ylim([0, 12])
    #ax.plot(x3, sodarw3[:,level], label='sodarW')
    #ax.plot(x3, wrf1[t3:t4, level], label=expnames[0], linewidth=lw)
    #ax.plot(x3, wrf2[t3:t4, level], label=expnames[1], linewidth=lw)
    #ax.plot(x3, wrf3[t3:t4, level], label=expnames[2], linewidth=lw)
    #ax.plot(x3, wrf4[t3:t4, level], label=expnames[3], linewidth=lw)
    #ax.plot(x3, wrf5[t3:t4, level], label=expnames[4], linewidth=lw)
    #ax.plot(x3, wrf6[t3:t4, level], label=expnames[5], linewidth=lw)
    #ax.legend();

    ax = axs[1, 0]
    ax.set_ylim([0, 12])
    ax.plot(x1, sodarw1[:,level], label='sodarW')
    ax.plot(x1, wrf7[t1:t2, level], label=expnames[6], linewidth=lw)
    ax.plot(x1, wrf8[t1:t2, level], label=expnames[7], linewidth=lw)
    ax.plot(x1, wrf9[t1:t2, level], label=expnames[8], linewidth=lw)
    ax.plot(x1, wrf10[t1:t2, level], label=expnames[9], linewidth=lw)
    ax.plot(x1, wrf11[t1:t2, level], label=expnames[10], linewidth=lw)
    ax.plot(x1, wrf12[t1:t2, level], label=expnames[11], linewidth=lw)
    ax.legend();

    ax = axs[1, 1]
    ax.set_ylim([0, 12])
    ax.plot(x2, sodarw2[:,level], label='sodarW')

    ax.plot(x2, wrf7[t2:t3, level], label=expnames[6], linewidth=lw)
    ax.plot(x2, wrf8[t2:t3, level], label=expnames[7], linewidth=lw)
    ax.plot(x2, wrf9[t2:t3, level], label=expnames[8], linewidth=lw)
    ax.plot(x2, wrf10[t2:t3, level], label=expnames[9], linewidth=lw)
    ax.plot(x2, wrf11[t2:t3, level], label=expnames[10], linewidth=lw)
    ax.plot(x2, wrf12[t2:t3, level], label=expnames[11], linewidth=lw)
    ax.legend();

    #ax = axs[1, 2]
    #ax.set_ylim([0, 12])
    #ax.plot(x3, sodarw3[:,level], label='sodarW')
    #ax.plot(x3, wrf7[t3:t4, level], label=expnames[6], linewidth=lw)
    #ax.plot(x3, wrf8[t3:t4, level], label=expnames[7], linewidth=lw)
    #ax.plot(x3, wrf9[t3:t4, level], label=expnames[8], linewidth=lw)
    #ax.plot(x3, wrf10[t3:t4, level], label=expnames[9], linewidth=lw)
    #ax.plot(x3, wrf11[t3:t4, level], label=expnames[10], linewidth=lw)
    #ax.plot(x3, wrf12[t3:t4, level], label=expnames[11], linewidth=lw)
    #ax.legend();

    plt.title('Wind Speed SODAR & WRF at '+zlevels[level]+'m', x=0.0, y=2.25)


    #print(level, skey, wkey)
    #plt.savefig('figs/panelPlotd'+skey+'.png', dpi=300)

# %%
x1 = sread_w.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].index
x2 = sread_w.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].index
sodarw1 = sread_w.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodarw2 = sread_w.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values
sodart1 = sread_t.iloc[:,ids]['2012-08-17 00:30':'2012-08-18 00:00'].interpolate().values
sodart2 = sread_t.iloc[:,ids]['2012-08-18 00:30':'2012-08-19 00:00'].interpolate().values

def panelPlot4(level):
    #skey = sodart1.keys()[level*1000]
    #wkey = tv1.interp_level.values*1000
    fig, axs = plt.subplots(2, 2, figsize=(15,9))
    fig.subplots_adjust(left=0.08, right=0.98, wspace=0.1, hspace=0.2)
    for axl in range(0,2):
        for axc in range(0,2):
            plt.setp( axs[axl,axc].xaxis.get_majorticklabels(), rotation=25 )
            axs[axl,axc].grid()
            axs[0,0].set_ylabel('Virtual Temperature')
            axs[1,0].set_ylabel('Virtual Temperature')
    lw = 0.6
    ax = axs[0, 0]
    tl, th = 20, 34
    ax.set_ylim([tl, th])
    ax.plot(x1, sodart1[:,level], label='sodart')
    ax.plot(x1, tv1[t1:t2, level], label=expnames[0], linewidth=lw)
    ax.plot(x1, tv2[t1:t2, level], label=expnames[1], linewidth=lw)
    ax.plot(x1, tv3[t1:t2, level], label=expnames[2], linewidth=lw)
    ax.plot(x1, tv4[t1:t2, level], label=expnames[3], linewidth=lw)
    ax.plot(x1, tv5[t1:t2, level], label=expnames[4], linewidth=lw)
    ax.plot(x1, tv6[t1:t2, level], label=expnames[5], linewidth=lw)
    ax.legend();

    ax = axs[0, 1]
    ax.set_ylim([tl, th])
    ax.plot(x2, sodart2[:,level], label='sodart')
    ax.plot(x2, tv1[t2:t3, level], label=expnames[0], linewidth=lw)
    ax.plot(x2, tv2[t2:t3, level], label=expnames[1], linewidth=lw)
    ax.plot(x2, tv3[t2:t3, level], label=expnames[2], linewidth=lw)
    ax.plot(x2, tv4[t2:t3, level], label=expnames[3], linewidth=lw)
    ax.plot(x2, tv5[t2:t3, level], label=expnames[4], linewidth=lw)
    ax.plot(x2, tv6[t2:t3, level], label=expnames[5], linewidth=lw)
    ax.legend();

    #ax = axs[0, 2]
    #ax.set_ylim([tl, th])
    #ax.plot(x3, sodart3[:,level], label='sodart')
    #ax.plot(x3, tv1[t3:t4, level], label=expnames[0], linewidth=lw)
    #ax.plot(x3, tv2[t3:t4, level], label=expnames[1], linewidth=lw)
    #ax.plot(x3, tv3[t3:t4, level], label=expnames[2], linewidth=lw)
    #ax.plot(x3, tv4[t3:t4, level], label=expnames[3], linewidth=lw)
    #ax.plot(x3, tv5[t3:t4, level], label=expnames[4], linewidth=lw)
    #ax.plot(x3, tv6[t3:t4, level], label=expnames[5], linewidth=lw)
    #ax.legend();

    ax = axs[1, 0]
    ax.set_ylim([tl, th])
    ax.plot(x1, sodart1[:,level], label='sodart')
    ax.plot(x1, tv7[t1:t2, level], label=expnames[6], linewidth=lw)
    ax.plot(x1, tv8[t1:t2, level], label=expnames[7], linewidth=lw)
    ax.plot(x1, tv9[t1:t2, level], label=expnames[8], linewidth=lw)
    ax.plot(x1, tv10[t1:t2, level], label=expnames[9], linewidth=lw)
    ax.plot(x1, tv11[t1:t2, level], label=expnames[10], linewidth=lw)
    ax.plot(x1, tv12[t1:t2, level], label=expnames[11], linewidth=lw)
    ax.legend();

    ax = axs[1, 1]
    ax.set_ylim([tl, th])
    ax.plot(x2, sodart2[:,level], label='sodart')
    ax.plot(x2, tv7[t2:t3, level], label=expnames[6], linewidth=lw)
    ax.plot(x2, tv8[t2:t3, level], label=expnames[7], linewidth=lw)
    ax.plot(x2, tv9[t2:t3, level], label=expnames[8], linewidth=lw)
    ax.plot(x2, tv10[t2:t3, level], label=expnames[9], linewidth=lw)
    ax.plot(x2, tv11[t2:t3, level], label=expnames[10], linewidth=lw)
    ax.plot(x2, tv12[t2:t3, level], label=expnames[11], linewidth=lw)
    ax.legend();

    #ax = axs[1, 2]
    #ax.set_ylim([tl, th])
    #ax.plot(x3, sodart3[:,level], label='sodart')
    #ax.plot(x3, tv7[t3:t4, level], label=expnames[6], linewidth=lw)
    #ax.plot(x3, tv8[t3:t4, level], label=expnames[7], linewidth=lw)
    #ax.plot(x3, tv9[t3:t4, level], label=expnames[8], linewidth=lw)
    #ax.plot(x3, tv10[t3:t4, level], label=expnames[9], linewidth=lw)
    #ax.plot(x3, tv11[t3:t4, level], label=expnames[10], linewidth=lw)
    #ax.plot(x3, tv12[t3:t4, level], label=expnames[11], linewidth=lw)
    #ax.legend();

    #plt.suptitle('Virtual Temperature ');
    plt.title('Virtual Temp SODAR & WRF at '+zlevels[level]+'m', x=0.0, y=2.25)

    #print(level, skey, wkey)
    #plt.savefig('figs/panelPlotd'+skey+'.png', dpi=300)

# %%
t1, t2, t3, t4 = 24, 72, 120, 144
panelPlot3(level=3)
panelPlot4(level=3)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# t1, t2, t3, t4 = 24, 72, 120, 144
panelPlot3(level=2)
#panelPlot4(level=3)

# %%
from netCDF4 import Dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import wrf
from wrf import getvar, vinterp, ALL_TIMES, destagger, to_np, interplevel

# %%
def hovtslon(tt, ln, ax=None):
    plt.figure(figsize=(12,6))
    if ax is None:
        ax = plt.gca()
    tvhv = wrf3d['tv30'][tt,:,:,ln]
    ua = wrf3d['ua30'][tt,:,:,ln]
    va = wrf3d['va30'][tt,:,:,ln]
    wa = wrf3d['wa30'][tt,:,:,ln]
    uv = np.sqrt(np.power(va,2)+np.power(wa,2))
    wdr = np.arctan2(-va,-ua) 
    wdd = np.degrees(wdr)
    # https://www.eol.ucar.edu/content/wind-direction-quick-reference
    phov = wrf3d['p30'][tt,:,:,ln]
    zhov = wrf3d['z30'][tt,:,:,ln]
    
    lats = wrf3d.coords['XLAT'][:,ln]
    lats = np.array([lats,]*12)
    lon = np.mean(wrf3d.coords['XLONG'][:,ln].values)

    #vmin, vmax = 0, 11
    #levels = np.arange(vmin,vmax,0.5)
    plt.contourf(lats, zhov, np.abs(va), cmap='rainbow')  #, levels=levels, vmin=vmin, vmax=vmax,
    plt.colorbar();
    
    vmin, vmax = 20, 35
    levels = np.arange(vmin,vmax,1)
    #manual_locations = [(0, 0), (0, 1), (0, 2), (0, 3), (0, 3)]
    #plt.clabel(CS, inline=1, fontsize=10, manual=manual_locations)

    CS = ax.contour(lats, zhov, tvhv, colors='w', levels=levels)
    ax.clabel(CS, inline=1, fmt='%2.1f', colors='w', fontsize=10)

    Q = ax.quiver(lats, zhov, -va, wa)
    wplot = ax.quiverkey(Q, X=0.85, Y=1.05, U=2, label='Vector = 2 m/s', labelpos='E')
    #  pd.to_datetime(str(date)) 
    ts = pd.to_datetime(ua.Time.values)
    ts = ts.strftime('%Y%m%d-%Hh')
    ax.invert_xaxis()
    plt.title('Wind Speed Contours for LLJ \n at LON {:.2f}'.format(lon)+' Valid at '+ts)
    
    # print("FORMAT".format(NUMBER));
    #  https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.quiverkey.html#matplotlib.axes.Axes.quiverkey

# %%
tt, ln = 38, 20
wrf3d = xr.open_dataset('interp30/g1r3.nc')
hovtslon(tt=tt, ln=ln)
#hovtslon(tt=tt+2, ln=ln)
#hovtslon(tt=tt+4, ln=ln)
#hovtslon(tt=tt+6, ln=ln)

# %%
tt, ln = 44+38, 20

for ncfile in expnames:
    wrf3d = xr.open_dataset('interp30/'+str(ncfile)+'.nc')
    hovtslon(tt=tt, ln=ln)
    plt.suptitle(str(ncfile));

# %%
tt, ln = 12, 20
wrf3d = xr.open_dataset('interp30/g1r3.nc')

tvhv = wrf3d['tv30'][tt,:,:,ln]
ua = wrf3d['ua30'][tt,:,:,ln]
va = wrf3d['va30'][tt,:,:,ln]
wa = wrf3d['wa30'][tt,:,:,ln]
uv = np.sqrt(np.power(ua,2)+np.power(va,2))
wdr = np.arctan2(-ua,-va) 
wdd = np.degrees(wdr)+270
phov = wrf3d['p30'][tt,:,:,ln]
zhov = wrf3d['z30'][tt,:,:,ln]
whov = wrf3d['wa30'][tt,:,:,ln]

#  pd.to_datetime(str(date)) 
ts = sread_w.index[tt]
ts = ts.strftime('%Y%m%d-%Hh')
ts
# Out:
# '20120816-06h'

# %%
ProfilesPanel1(tt=24+36+20)
ProfilesPanel1(tt=24+38+20)
ProfilesPanel1(tt=24+40+20)

print('\n\n')

ProfilesPanel1(tt=72+36)
ProfilesPanel1(tt=72+38)
ProfilesPanel1(tt=72+40)

# %%
#ProfilesPanel2(24,29,2,wrf1)
#plt.savefig('figs/Sea Breeze d17_17h_png', dpi=300)
#ProfilesPanel2(48,57,2,wrf2)
