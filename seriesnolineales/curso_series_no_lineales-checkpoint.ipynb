# %%
x0=1
y0=1
a=1.4
b=0.3
for i in range(500000):
    x1=1-a*x0*x0+y0
    y1=b*x0
    x0=x1
    y0=y1
    #print x1,y1

# %%
import pandas as pd 
lore = pd.read_csv('lore.dat', header=None, delimiter=' ', names=['x', 'y', 'z'] )
#lore['y']

# %%
import matplotlib.pyplot as plt
plt.plot(lore['y'])

# %% [markdown]
# Peliculas mejorenvo
# Si yo hubiera
# Corre Lola
# Lorenz System
# Matematico Takens
# Graficar Xt, Xt+1  (Diagrama de recurrencia)  # SI la relacion es funcional, proviene de us sistema determinista
# x+tau,  x+2tau
# Horizonte de predictibilidad (4 dias)

# %% [markdown]
# Reconstruir el detractor de henon
# Diagrama de recurrencia
# libgen
# Fractals, Chaos, Power Laws,  Schroeder
# Nonlinear Time Series Analisys, Kantz & Schreiber     (Paquete Tisean, FRACTALES)  Arxiv
# Dimension fractal, box counting, dimension de correlacion
#
#
# sudo apt install julia
# julia benchmark

# %% [markdown]
# Preguntas
# Dimension fractal para grados de libertad para explicar fenomeno de senal.
# https://en.wikipedia.org/wiki/Lorenz_system
# https://en.wikipedia.org/wiki/Floris_Takens
# http://www.miscelaneamatematica.org/Misc58.1/58101.pdf
# http://lya.fciencias.unam.mx/biomat/pedro/publicaciones.html
# http://lya.fciencias.unam.mx/biomat/pedro/Python/
# https://en.wikipedia.org/wiki/H%C3%A9non_map
# https://en.wikipedia.org/wiki/Colors_of_noise
